# %%
import errno
import matplotlib.pyplot as plt
import numpy as np
import cv2
import pandas as pd
from shapely.wkt import loads as wkt_loads
import tifffile as tiff
import os
import random
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as K
from keras.models import load_model
from sklearn.metrics import jaccard_similarity_score
from shapely.geometry import MultiPolygon, Polygon
import shapely.wkt
import shapely.affinity
from collections import defaultdict

import csv
import glob
import gdal

from datetime import datetime

from keras import __version__
print(__version__)
# Out:
# Using TensorFlow backend.
# 2.0.5

# %%
def mkdir_p(path):
    try:
        os.makedirs(path)
    except OSError as exc:  # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise

K.set_image_data_format('channels_first')

N_Cls = 1
data_base_dir = "/home/ubuntu/data/"
inDir = './'
mkdir_p(inDir + '/data')
out_dir = 'output/'
mkdir_p(out_dir)

print(os.getcwd())
DF = pd.read_csv(data_base_dir+'train_wkt_v4_TREES.csv')
val_DF = pd.read_csv(data_base_dir+'val_wkt_v4_TREES.csv')
GS = pd.read_csv(data_base_dir+'grid_sizes.csv', names=['ImageId', 'Xmax', 'Ymin'], skiprows=1)
SB = pd.read_csv(data_base_dir+'sample_submission.csv')

ISZ = 160
smooth = 1e-12

EPSILON = 2  # polygon edge smoothing factor (higher=less nodes, i.e. less detail)
MIN_AREA = 5.  # smallest area a polygon can be

val_img_names = ["6010_4_4", "6070_2_3", "6100_2_3", "6140_1_2", "6110_4_0"]
# Out:
# /home/ubuntu/git/kaggle-dstl/keras2-baseline-improvements

# %% [markdown]
# # Image preprocessing

# %% [markdown]
# ## Create indexes (all test/train/val TIFFs)

# %%
def get_bands(src):
    red = src.GetRasterBand(5)
    nir = src.GetRasterBand(7)
    blue = src.GetRasterBand(2)

    r_arr = red.ReadAsArray()
    nir_arr = nir.ReadAsArray()
    b_arr = blue.ReadAsArray()

    r_arr = r_arr.astype(np.float32)
    nir_arr = nir_arr.astype(np.float32)
    b_arr = b_arr.astype(np.float32)

    return r_arr, nir_arr, b_arr


def ndvi_calc(red, nir):
    # https://en.wikipedia.org/wiki/Normalized_Difference_Vegetation_Index
    return ((nir - red) / (nir + red))


def evi_calc(r_arr, nir_arr, b_arr,
             canopy_background_adjustment,
             coefficient_1_of_the_aerosol_resistance_term,
             coefficient_2_of_the_aerosol_resistance_term,
             gain_factor):
    # https://en.wikipedia.org/wiki/Enhanced_vegetation_index
    L = canopy_background_adjustment
    C1 = coefficient_1_of_the_aerosol_resistance_term
    C2 = coefficient_2_of_the_aerosol_resistance_term
    G = gain_factor
    return G * (nir_arr - r_arr) / (nir_arr + C1*r_arr - C2*b_arr + L)


def get_scalers(x_max, y_min, im_size):
    h, w = im_size  # they are flipped so that mask_for_polygons works correctly
    w_ = w * (w / (w + 1))
    h_ = h * (h / (h + 1))
    return w_ / x_max, h_ / y_min


# "With the value for L used, this is essentially the same computation as NDVI - hence commented out.
# (indeed, the visualisation of the index bands indicate the similarity)."
def savi_calc(r_arr, nir_arr, canopy_background_adjustment_factor):
    # https: // en.wikipedia.org / wiki / Soil - Adjusted_Vegetation_Index   
    L = canopy_background_adjustment_factor
    return ((1 + L)*(nir_arr - r_arr)) / (nir_arr + r_arr + L)



def get_bands(src):
    red = src.GetRasterBand(5)
    nir = src.GetRasterBand(7)
    blue = src.GetRasterBand(2)

    r_arr = red.ReadAsArray()
    nir_arr = nir.ReadAsArray()
    b_arr = blue.ReadAsArray()

    r_arr = r_arr.astype(np.float32)
    nir_arr = nir_arr.astype(np.float32)
    b_arr = b_arr.astype(np.float32)

    return r_arr, nir_arr, b_arr


def get_xmax_ymin(imageid):
    for _im_id, _x, _y in csv.reader(open(data_base_dir + "/grid_sizes.csv")):
        if _im_id == imageid:
            x_max, y_min = float(_x), float(_y)
            return x_max, y_min


def create_indexes(image_id):
#     ndvi_all = []
#     evi_all = []
#     savi_all = []
    
    m_path = data_base_dir + "sixteen_band/{}_M.tif".format(image_id)
    imageid = m_path.split("/")[-1].split("_M.tif")[0]

    src = gdal.Open(m_path)

    r_arr, nir_arr, b_arr = get_bands(src)

    im_size = r_arr.shape

    x_max, y_min = get_xmax_ymin(imageid)

    x_scaler, y_scaler = get_scalers(x_max, y_min, im_size)

    ndvi = ndvi_calc(r_arr, nir_arr)
    evi = evi_calc(r_arr, nir_arr, b_arr,
         canopy_background_adjustment=1,
         coefficient_1_of_the_aerosol_resistance_term=6,
         coefficient_2_of_the_aerosol_resistance_term=7.5,
         gain_factor=2.5)
    savi = savi_calc(r_arr, nir_arr, canopy_background_adjustment_factor=0.5)

    return ndvi, savi, evi
#     ndvi_all.append(ndvi)
#     evi_all.append(evi)
#     savi_all.append(savi)

#     np.save(inDir + '/data/ndvi_all', np.array(ndvi_all))
#     np.save(inDir + '/data/evi_all', np.array(evi_all))
#     np.save(inDir + '/data/savi_all', np.array(savi_all))

# %% [markdown]
# ## tweaked code for including indexes

# %%
def _convert_coordinates_to_raster(coords, img_size, xymax):
    # __author__ = visoft
    # https://www.kaggle.com/visoft/dstl-satellite-imagery-feature-detection/export-pixel-wise-mask
    Xmax, Ymax = xymax
    H, W = img_size
    W1 = 1.0 * W * W / (W + 1)
    H1 = 1.0 * H * H / (H + 1)
    xf = W1 / Xmax
    yf = H1 / Ymax
    coords[:, 1] *= yf
    coords[:, 0] *= xf
    coords_int = np.round(coords).astype(np.int32)
    return coords_int


def _get_xmax_ymin(grid_sizes_panda, imageId):
    # __author__ = visoft
    # https://www.kaggle.com/visoft/dstl-satellite-imagery-feature-detection/export-pixel-wise-mask
    xmax, ymin = grid_sizes_panda[grid_sizes_panda.ImageId == imageId].iloc[0, 1:].astype(float)
    return (xmax, ymin)


def _get_polygon_list(wkt_list_pandas, imageId, cType):
    # __author__ = visoft
    # https://www.kaggle.com/visoft/dstl-satellite-imagery-feature-detection/export-pixel-wise-mask
    df_image = wkt_list_pandas[wkt_list_pandas.ImageId == imageId]
    multipoly_def = df_image[df_image.ClassType == cType].MultipolygonWKT
    polygonList = None
    if len(multipoly_def) > 0:
        assert len(multipoly_def) == 1
        polygonList = wkt_loads(multipoly_def.values[0])
    return polygonList


def _get_and_convert_contours(polygonList, raster_img_size, xymax):
    # __author__ = visoft
    # https://www.kaggle.com/visoft/dstl-satellite-imagery-feature-detection/export-pixel-wise-mask
    perim_list = []
    interior_list = []
    if polygonList is None:
        return None
    for k in range(len(polygonList)):
        poly = polygonList[k]
        perim = np.array(list(poly.exterior.coords))
        perim_c = _convert_coordinates_to_raster(perim, raster_img_size, xymax)
        perim_list.append(perim_c)
        for pi in poly.interiors:
            interior = np.array(list(pi.coords))
            interior_c = _convert_coordinates_to_raster(interior, raster_img_size, xymax)
            interior_list.append(interior_c)
    return perim_list, interior_list


def _plot_mask_from_contours(raster_img_size, contours, class_value=1):
    # __author__ = visoft
    # https://www.kaggle.com/visoft/dstl-satellite-imagery-feature-detection/export-pixel-wise-mask
    img_mask = np.zeros(raster_img_size, np.uint8)
    if contours is None:
        return img_mask
    perim_list, interior_list = contours
    cv2.fillPoly(img_mask, perim_list, class_value)
    cv2.fillPoly(img_mask, interior_list, 0)
    return img_mask


def generate_mask_for_image_and_class(raster_size, imageId, class_type, grid_sizes_panda=GS, wkt_list_pandas=DF):
    # __author__ = visoft
    # https://www.kaggle.com/visoft/dstl-satellite-imagery-feature-detection/export-pixel-wise-mask
    xymax = _get_xmax_ymin(grid_sizes_panda, imageId)  # for scaling according to competition
    polygon_list = _get_polygon_list(wkt_list_pandas, imageId, class_type)  # read (training) polygon data
    contours = _get_and_convert_contours(polygon_list, raster_size, xymax)  # creating outline from vector nodes
    mask = _plot_mask_from_contours(raster_size, contours, 1)  # filling in polygon outlines (i.e. creating the mask)
    return mask


def M(image_id):
    # __author__ = amaia
    # https://www.kaggle.com/aamaia/dstl-satellite-imagery-feature-detection/rgb-using-m-bands-example
    filename = os.path.join(data_base_dir, 'sixteen_band', '{}_M.tif'.format(image_id))
    img = tiff.imread(filename)
    img = np.rollaxis(img, 0, 3)
    return img


def stretch_n(bands, lower_percent=0, higher_percent=100): # <- "Claims to improve" (was lower_percent=5, higher_percent=95)
    # "Contrast enhancement", see https://www.kaggle.com/aamaia/rgb-using-m-bands-example
    out = np.zeros_like(bands).astype(np.float32)
    n = bands.shape[2]
    for i in range(n):
        a = 0  # np.min(band)
        b = 1  # np.max(band)
        c = np.percentile(bands[:, :, i], lower_percent)
        d = np.percentile(bands[:, :, i], higher_percent)
        t = a + (bands[:, :, i] - c) * (b - a) / (d - c)
        t[t < a] = a
        t[t > b] = b
        out[:, :, i] = t

    return out.astype(np.float32)


def stick_all_train():
    print("let's stick all imgs together")
    s = 835  # size of the M images (roughly)

    # 25 training images grid
    x = np.zeros((5 * s, 4 * s, 8+3))     # +3 for the 3 indexes (ndvi, savi, evi)
    y = np.zeros((5 * s, 4 * s, N_Cls))   # axis=2 denote the class label

    ids = sorted(DF.ImageId.unique())
    print(len(ids))
    
    
    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(4):
            id = ids[1 * i + j]

            img = M(id)
        
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            x[s * i:s * i + s, s * j:s * j + s, :8] = img[:s, :s, :]
            
            # Add indexes from above
            ndvi, savi, evi = create_indexes(id)
            x[s * i:s * i + s, s * j:s * j + s, 8] = ndvi[:s, :s]
            x[s * i:s * i + s, s * j:s * j + s, 9] = savi[:s, :s]
            x[s * i:s * i + s, s * j:s * j + s, 10] = evi[:s, :s]
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1)[:s, :s]
    
    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))
    
    np.save(inDir + '/data/x_trn_%d' % N_Cls, x)
    np.save(inDir + '/data/y_trn_%d' % N_Cls, y)

    
def get_patches(img, msk, amt=10000, aug=True):
    is2 = int(1.0 * ISZ)  # ISZ=is2=patch size
    xm, ym = img.shape[0] - is2, img.shape[1] - is2  # starting coordinate for getting patches (taking into consideration padding)

    x, y = [], []

    # threshold determining when to add an image - if the image contains a greater percentage of pixels in the training
    # set than specified by the thresholds below:
    tr = [0.3]
    
    count = 0

    for i in range(amt):
        do_we_append = False
        
        # get random point in inner image (i.e exluding the outer image padding)
        xc = random.randint(0, xm)
        yc = random.randint(0, ym)

        # get patch
        im = img[xc:xc + is2, yc:yc + is2]
        ms = msk[xc:xc + is2, yc:yc + is2]

        for j in range(N_Cls):
            # sum pixels containing class j
            sm = np.sum(ms[:, :, j])
            if aug:
                if random.uniform(0, 1) > 0.5:
                    im = im[::-1]
                    ms = ms[::-1]
                if random.uniform(0, 1) > 0.5:
                    im = im[:, ::-1]
                    ms = ms[:, ::-1]

            # calculate the percent of covered pixels (for one class) - check if greater than threshold.
            if 1.0 * sm / is2 ** 2 > tr[j]:
                do_we_append = True
            
            # Add "blank ones" with probability 0.1
            elif sm < 500:
                do_we_append = True
                count += 1
                print("Add blank, idx={}, count={}".format(i, count))
            
        if do_we_append:
            x.append(im)
            y.append(ms)

    x, y = 2 * np.transpose(x, (0, 3, 1, 2)) - 1, np.transpose(y, (0, 3, 1, 2))  # Maybe some sort of standardisation/normalisation
    print(x.shape, y.shape, np.amax(x), np.amin(x), np.amax(y), np.amin(y))
    return x, y

# %%
 stick_all_train()  # sticking all training images in 5x5x10 grid (i.e. 5*M_pixels x 5*M_pixels x 10 classes)
                    # plus indexes

# %% [markdown]
# ## Create custom validation set

# %%
def make_val(aug=False):
    print("let's pick some samples for validation")
    img = np.load(inDir + '/data/x_valALL_%d.npy' % N_Cls)
    msk = np.load(inDir + '/data/y_valALL_%d.npy' % N_Cls)
    x, y = get_patches(img, msk, amt=3000, aug=aug)  # amt := attempt (maybe - i.e. attempting to create 3000 patches, without
                                            # percentage area cover threshold.

    print("Validation data shapes:")
    print(x.shape)
    print(y.shape)

    np.save(inDir + '/data/x_val_%d' % N_Cls, x)
    np.save(inDir + '/data/y_val_%d' % N_Cls, y)
    
    
def stick_all_val():
    print("let's stick all imgs together")
    s = 835  # size of the M images

    # 25 training images grid
    x = np.zeros((5 * s, 1 * s, 8+3))     # +3 for the 3 indexes (ndvi, savi, evi)
    y = np.zeros((5 * s, 1 * s, N_Cls))   # axis=2 denote the class label

    ids = sorted(val_DF.ImageId.unique())
    print(len(ids))

    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(1):
            id = ids[1 * i + j]

            img = M(id)
            
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            x[s * i:s * i + s, s * j:s * j + s, :8] = img[:s, :s, :]
            
            # Add indexes from above
            ndvi, savi, evi = create_indexes(id)
            x[s * i:s * i + s, s * j:s * j + s, 8] = ndvi[:s, :s]
            x[s * i:s * i + s, s * j:s * j + s, 9] = savi[:s, :s]
            x[s * i:s * i + s, s * j:s * j + s, 10] = evi[:s, :s]
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1, wkt_list_pandas=val_DF)[:s, :s]

    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))

    np.save(inDir + '/data/x_valALL_%d' % N_Cls, x)
    np.save(inDir + '/data/y_valALL_%d' % N_Cls, y)

# %%
# DONE IN BASELINE
stick_all_val()
make_val()
# Out:
# let's stick all imgs together
# 5
# (837, 848, 8) 6010_4_4 1.0 0.0
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in true_divide
# (838, 835, 8) 6070_2_3 1.0 0.0
# (837, 848, 8) 6100_2_3 1.0 0.0
# (837, 849, 8) 6110_4_0 1.0 0.0
# (837, 849, 8) 6140_1_2 1.0 0.0
# x shape is:
# (4175, 835, 11)
# y shape is:
# (4175, 835, 1)
# 1.0 0.0
# let's pick some samples for validation
# Add blank, idx=13, count=1
# Add blank, idx=34, count=2
# Add blank, idx=46, count=3
# Add blank, idx=61, count=4
# Add blank, idx=64, count=5
# Add blank, idx=65, count=6
# Add blank, idx=67, count=7
# Add blank, idx=77, count=8
# Add blank, idx=82, count=9
# Add blank, idx=94, count=10
# Add blank, idx=96, count=11
# Add blank, idx=98, count=12
# Add blank, idx=102, count=13
# Add blank, idx=104, count=14
# Add blank, idx=109, count=15
# Add blank, idx=121, count=16
# Add blank, idx=122, count=17
# Add blank, idx=125, count=18
# Add blank, idx=139, count=19
# Add blank, idx=147, count=20
# Add blank, idx=150, count=21
# Add blank, idx=158, count=22
# Add blank, idx=159, count=23
# Add blank, idx=174, count=24
# Add blank, idx=177, count=25
# Add blank, idx=178, count=26
# Add blank, idx=181, count=27
# Add blank, idx=186, count=28
# Add blank, idx=217, count=29
# Add blank, idx=220, count=30
# Add blank, idx=228, count=31
# Add blank, idx=235, count=32
# Add blank, idx=241, count=33
# Add blank, idx=254, count=34
# Add blank, idx=255, count=35
# Add blank, idx=258, count=36
# Add blank, idx=262, count=37
# Add blank, idx=263, count=38
# Add blank, idx=264, count=39
# Add blank, idx=266, count=40
# Add blank, idx=268, count=41
# Add blank, idx=269, count=42
# Add blank, idx=275, count=43
# Add blank, idx=277, count=44
# Add blank, idx=281, count=45
# Add blank, idx=286, count=46
# Add blank, idx=287, count=47
# Add blank, idx=294, count=48
# Add blank, idx=296, count=49
# Add blank, idx=297, count=50
# Add blank, idx=300, count=51
# Add blank, idx=321, count=52
# Add blank, idx=334, count=53
# Add blank, idx=337, count=54
# Add blank, idx=343, count=55
# Add blank, idx=354, count=56
# Add blank, idx=356, count=57
# Add blank, idx=366, count=58
# Add blank, idx=372, count=59
# Add blank, idx=373, count=60
# Add blank, idx=375, count=61
# Add blank, idx=380, count=62
# Add blank, idx=382, count=63
# Add blank, idx=384, count=64
# Add blank, idx=390, count=65
# Add blank, idx=402, count=66
# Add blank, idx=429, count=67
# Add blank, idx=430, count=68
# Add blank, idx=432, count=69
# Add blank, idx=441, count=70
# Add blank, idx=450, count=71
# Add blank, idx=454, count=72
# Add blank, idx=462, count=73
# Add blank, idx=475, count=74
# Add blank, idx=480, count=75
# Add blank, idx=497, count=76
# Add blank, idx=500, count=77
# Add blank, idx=501, count=78
# Add blank, idx=514, count=79
# Add blank, idx=542, count=80
# Add blank, idx=545, count=81
# Add blank, idx=548, count=82
# Add blank, idx=566, count=83
# Add blank, idx=567, count=84
# Add blank, idx=568, count=85
# Add blank, idx=569, count=86
# Add blank, idx=572, count=87
# Add blank, idx=574, count=88
# Add blank, idx=581, count=89
# Add blank, idx=586, count=90
# Add blank, idx=587, count=91
# Add blank, idx=590, count=92
# Add blank, idx=595, count=93
# Add blank, idx=598, count=94
# Add blank, idx=602, count=95
# Add blank, idx=604, count=96
# Add blank, idx=605, count=97
# Add blank, idx=618, count=98
# Add blank, idx=624, count=99
# Add blank, idx=628, count=100
# Add blank, idx=631, count=101
# Add blank, idx=666, count=102
# Add blank, idx=671, count=103
# Add blank, idx=673, count=104
# Add blank, idx=679, count=105
# Add blank, idx=681, count=106
# Add blank, idx=698, count=107
# Add blank, idx=701, count=108
# Add blank, idx=704, count=109
# Add blank, idx=716, count=110
# Add blank, idx=722, count=111
# Add blank, idx=730, count=112
# Add blank, idx=733, count=113
# Add blank, idx=740, count=114
# Add blank, idx=741, count=115
# Add blank, idx=763, count=116
# Add blank, idx=780, count=117
# Add blank, idx=785, count=118
# Add blank, idx=791, count=119
# Add blank, idx=792, count=120
# Add blank, idx=806, count=121
# Add blank, idx=816, count=122
# Add blank, idx=823, count=123
# Add blank, idx=831, count=124
# Add blank, idx=843, count=125
# Add blank, idx=849, count=126
# Add blank, idx=850, count=127
# Add blank, idx=866, count=128
# Add blank, idx=881, count=129
# Add blank, idx=895, count=130
# Add blank, idx=909, count=131
# Add blank, idx=927, count=132
# Add blank, idx=930, count=133
# Add blank, idx=938, count=134
# Add blank, idx=958, count=135
# Add blank, idx=959, count=136
# Add blank, idx=968, count=137
# Add blank, idx=982, count=138
# Add blank, idx=984, count=139
# Add blank, idx=985, count=140
# Add blank, idx=996, count=141
# Add blank, idx=1001, count=142
# Add blank, idx=1023, count=143
# Add blank, idx=1028, count=144
# Add blank, idx=1032, count=145
# Add blank, idx=1040, count=146
# Add blank, idx=1047, count=147
# Add blank, idx=1062, count=148
# Add blank, idx=1063, count=149
# Add blank, idx=1076, count=150
# Add blank, idx=1085, count=151
# Add blank, idx=1094, count=152
# Add blank, idx=1107, count=153
# Add blank, idx=1115, count=154
# Add blank, idx=1122, count=155
# Add blank, idx=1126, count=156
# Add blank, idx=1128, count=157
# Add blank, idx=1157, count=158
# Add blank, idx=1160, count=159
# Add blank, idx=1164, count=160
# Add blank, idx=1184, count=161
# Add blank, idx=1192, count=162
# Add blank, idx=1195, count=163
# Add blank, idx=1198, count=164
# Add blank, idx=1223, count=165
# Add blank, idx=1229, count=166
# Add blank, idx=1232, count=167
# Add blank, idx=1233, count=168
# Add blank, idx=1235, count=169
# Add blank, idx=1241, count=170
# Add blank, idx=1243, count=171
# Add blank, idx=1252, count=172
# Add blank, idx=1274, count=173
# Add blank, idx=1292, count=174
# Add blank, idx=1293, count=175
# Add blank, idx=1296, count=176
# Add blank, idx=1297, count=177
# Add blank, idx=1308, count=178
# Add blank, idx=1313, count=179
# Add blank, idx=1317, count=180
# Add blank, idx=1320, count=181
# Add blank, idx=1324, count=182
# Add blank, idx=1334, count=183
# Add blank, idx=1336, count=184
# Add blank, idx=1343, count=185
# Add blank, idx=1351, count=186
# Add blank, idx=1352, count=187
# Add blank, idx=1353, count=188
# Add blank, idx=1358, count=189
# Add blank, idx=1368, count=190
# Add blank, idx=1378, count=191
# Add blank, idx=1392, count=192
# Add blank, idx=1397, count=193
# Add blank, idx=1432, count=194
# Add blank, idx=1450, count=195
# Add blank, idx=1452, count=196
# Add blank, idx=1471, count=197
# Add blank, idx=1482, count=198
# Add blank, idx=1483, count=199
# Add blank, idx=1490, count=200
# Add blank, idx=1492, count=201
# Add blank, idx=1497, count=202
# Add blank, idx=1511, count=203
# Add blank, idx=1513, count=204
# Add blank, idx=1519, count=205
# Add blank, idx=1528, count=206
# Add blank, idx=1531, count=207
# Add blank, idx=1543, count=208
# Add blank, idx=1549, count=209
# Add blank, idx=1553, count=210
# Add blank, idx=1568, count=211
# Add blank, idx=1570, count=212
# Add blank, idx=1576, count=213
# Add blank, idx=1583, count=214
# Add blank, idx=1584, count=215
# Add blank, idx=1585, count=216
# Add blank, idx=1608, count=217
# Add blank, idx=1633, count=218
# Add blank, idx=1638, count=219
# Add blank, idx=1641, count=220
# Add blank, idx=1664, count=221
# Add blank, idx=1667, count=222
# Add blank, idx=1684, count=223
# Add blank, idx=1686, count=224
# Add blank, idx=1699, count=225
# Add blank, idx=1701, count=226
# Add blank, idx=1703, count=227
# Add blank, idx=1712, count=228
# Add blank, idx=1717, count=229
# Add blank, idx=1731, count=230
# Add blank, idx=1744, count=231
# Add blank, idx=1748, count=232
# Add blank, idx=1754, count=233
# Add blank, idx=1760, count=234
# Add blank, idx=1761, count=235
# Add blank, idx=1772, count=236
# Add blank, idx=1782, count=237
# Add blank, idx=1793, count=238
# Add blank, idx=1812, count=239
# Add blank, idx=1814, count=240
# Add blank, idx=1818, count=241
# Add blank, idx=1821, count=242
# Add blank, idx=1826, count=243
# Add blank, idx=1840, count=244
# Add blank, idx=1862, count=245
# Add blank, idx=1863, count=246
# Add blank, idx=1881, count=247
# Add blank, idx=1894, count=248
# Add blank, idx=1897, count=249
# Add blank, idx=1912, count=250
# Add blank, idx=1914, count=251
# Add blank, idx=1918, count=252
# Add blank, idx=1928, count=253
# Add blank, idx=1933, count=254
# Add blank, idx=1934, count=255
# Add blank, idx=1935, count=256
# Add blank, idx=1939, count=257
# Add blank, idx=1941, count=258
# Add blank, idx=1948, count=259
# Add blank, idx=1952, count=260
# Add blank, idx=1960, count=261
# Add blank, idx=1963, count=262
# Add blank, idx=1969, count=263
# Add blank, idx=1978, count=264
# Add blank, idx=1985, count=265
# Add blank, idx=1990, count=266
# Add blank, idx=1994, count=267
# Add blank, idx=2008, count=268
# Add blank, idx=2015, count=269
# Add blank, idx=2024, count=270
# Add blank, idx=2028, count=271
# Add blank, idx=2039, count=272
# Add blank, idx=2046, count=273
# Add blank, idx=2048, count=274
# Add blank, idx=2052, count=275
# Add blank, idx=2054, count=276
# Add blank, idx=2065, count=277
# Add blank, idx=2066, count=278
# Add blank, idx=2069, count=279
# Add blank, idx=2070, count=280
# Add blank, idx=2079, count=281
# Add blank, idx=2086, count=282
# Add blank, idx=2087, count=283
# Add blank, idx=2092, count=284
# Add blank, idx=2096, count=285
# Add blank, idx=2120, count=286
# Add blank, idx=2125, count=287
# Add blank, idx=2135, count=288
# Add blank, idx=2149, count=289
# Add blank, idx=2162, count=290
# Add blank, idx=2170, count=291
# Add blank, idx=2206, count=292
# Add blank, idx=2212, count=293
# Add blank, idx=2215, count=294
# Add blank, idx=2231, count=295
# Add blank, idx=2235, count=296
# Add blank, idx=2241, count=297
# Add blank, idx=2243, count=298
# Add blank, idx=2256, count=299
# Add blank, idx=2270, count=300
# Add blank, idx=2281, count=301
# Add blank, idx=2300, count=302
# Add blank, idx=2303, count=303
# Add blank, idx=2316, count=304
# Add blank, idx=2321, count=305
# Add blank, idx=2340, count=306
# Add blank, idx=2360, count=307
# Add blank, idx=2364, count=308
# Add blank, idx=2382, count=309
# Add blank, idx=2397, count=310
# Add blank, idx=2412, count=311
# Add blank, idx=2415, count=312
# Add blank, idx=2421, count=313
# Add blank, idx=2430, count=314
# Add blank, idx=2434, count=315
# Add blank, idx=2444, count=316
# Add blank, idx=2453, count=317
# Add blank, idx=2457, count=318
# Add blank, idx=2464, count=319
# Add blank, idx=2474, count=320
# Add blank, idx=2475, count=321
# Add blank, idx=2510, count=322
# Add blank, idx=2518, count=323
# Add blank, idx=2537, count=324
# Add blank, idx=2542, count=325
# Add blank, idx=2551, count=326
# Add blank, idx=2554, count=327
# Add blank, idx=2556, count=328
# Add blank, idx=2563, count=329
# Add blank, idx=2565, count=330
# Add blank, idx=2568, count=331
# Add blank, idx=2575, count=332
# Add blank, idx=2582, count=333
# Add blank, idx=2596, count=334
# Add blank, idx=2597, count=335
# Add blank, idx=2611, count=336
# Add blank, idx=2613, count=337
# Add blank, idx=2628, count=338
# Add blank, idx=2629, count=339
# Add blank, idx=2633, count=340
# Add blank, idx=2635, count=341
# Add blank, idx=2662, count=342
# Add blank, idx=2689, count=343
# Add blank, idx=2706, count=344
# Add blank, idx=2723, count=345
# Add blank, idx=2724, count=346
# Add blank, idx=2727, count=347
# Add blank, idx=2733, count=348
# Add blank, idx=2745, count=349
# Add blank, idx=2755, count=350
# Add blank, idx=2762, count=351
# Add blank, idx=2783, count=352
# Add blank, idx=2788, count=353
# Add blank, idx=2799, count=354
# Add blank, idx=2808, count=355
# Add blank, idx=2815, count=356
# Add blank, idx=2819, count=357
# Add blank, idx=2820, count=358
# Add blank, idx=2824, count=359
# Add blank, idx=2836, count=360
# Add blank, idx=2857, count=361
# Add blank, idx=2870, count=362
# Add blank, idx=2882, count=363
# Add blank, idx=2893, count=364
# Add blank, idx=2903, count=365
# Add blank, idx=2914, count=366
# Add blank, idx=2926, count=367
# Add blank, idx=2937, count=368
# Add blank, idx=2971, count=369
# Add blank, idx=2981, count=370
# Add blank, idx=2995, count=371
# (726, 11, 160, 160) (726, 1, 160, 160) inf -inf 1.0 0.0
# Validation data shapes:
# (726, 11, 160, 160)
# (726, 1, 160, 160)

# %% [markdown]
# ## Visualise indexes

# %%
x_val, y_val = np.load(inDir + '/data/x_val_%d.npy' % N_Cls), np.load(inDir + '/data/y_val_%d.npy' % N_Cls)
img = np.load(inDir + '/data/x_trn_%d.npy' % N_Cls)
msk = np.load(inDir + '/data/y_trn_%d.npy' % N_Cls)

# %%
import scipy.misc

def save_visual_msk_patch(np_arr, folder, sample_idx=0):
    scipy.misc.imsave("visualise/{}/{}msk.bmp".format(folder, sample_idx), np_arr[sample_idx][0])

def save_visual_img_patch(np_arr, folder, sample_idx=0, band=0):
    scipy.misc.imsave("visualise/{}/{}img_{}.bmp".format(folder, sample_idx, band), np_arr[sample_idx][band])

# %%
mkdir_p("visualise/trn")
mkdir_p("visualise/trn/ndvi")
mkdir_p("visualise/trn/savi")
mkdir_p("visualise/trn/evi")

x_trn, y_trn = get_patches(img, msk, amt=6000, aug=False)
for i in range(x_trn.shape[0]):
    save_visual_img_patch(x_trn, "trn", sample_idx=i)
    save_visual_img_patch(x_trn, "trn/ndvi", sample_idx=i, band=8)
    save_visual_img_patch(x_trn, "trn/savi", sample_idx=i, band=9)
    save_visual_img_patch(x_trn, "trn/evi", sample_idx=i, band=10)
    save_visual_msk_patch(y_trn, "trn", sample_idx=i)

print("Training data shapes:")
print(x_trn.shape)
print(y_trn.shape)
# Out:
# Add blank, idx=1, count=1
# Add blank, idx=3, count=2
# Add blank, idx=20, count=3
# Add blank, idx=78, count=4
# Add blank, idx=83, count=5
# Add blank, idx=96, count=6
# Add blank, idx=103, count=7
# Add blank, idx=115, count=8
# Add blank, idx=179, count=9
# Add blank, idx=196, count=10
# Add blank, idx=267, count=11
# Add blank, idx=303, count=12
# Add blank, idx=332, count=13
# Add blank, idx=340, count=14
# Add blank, idx=362, count=15
# Add blank, idx=366, count=16
# Add blank, idx=374, count=17
# Add blank, idx=419, count=18
# Add blank, idx=428, count=19
# Add blank, idx=452, count=20
# Add blank, idx=518, count=21
# Add blank, idx=522, count=22
# Add blank, idx=641, count=23
# Add blank, idx=698, count=24
# Add blank, idx=797, count=25
# Add blank, idx=826, count=26
# Add blank, idx=881, count=27
# Add blank, idx=919, count=28
# Add blank, idx=925, count=29
# Add blank, idx=932, count=30
# Add blank, idx=944, count=31
# Add blank, idx=962, count=32
# Add blank, idx=1000, count=33
# Add blank, idx=1031, count=34
# Add blank, idx=1060, count=35
# Add blank, idx=1105, count=36
# Add blank, idx=1138, count=37
# Add blank, idx=1151, count=38
# Add blank, idx=1160, count=39
# Add blank, idx=1184, count=40
# Add blank, idx=1201, count=41
# Add blank, idx=1208, count=42
# Add blank, idx=1224, count=43
# Add blank, idx=1240, count=44
# Add blank, idx=1268, count=45
# Add blank, idx=1280, count=46
# Add blank, idx=1297, count=47
# Add blank, idx=1337, count=48
# Add blank, idx=1367, count=49
# Add blank, idx=1392, count=50
# Add blank, idx=1423, count=51
# Add blank, idx=1451, count=52
# Add blank, idx=1484, count=53
# Add blank, idx=1520, count=54
# Add blank, idx=1535, count=55
# Add blank, idx=1572, count=56
# Add blank, idx=1581, count=57
# Add blank, idx=1590, count=58
# Add blank, idx=1601, count=59
# Add blank, idx=1610, count=60
# Add blank, idx=1667, count=61
# Add blank, idx=1673, count=62
# Add blank, idx=1675, count=63
# Add blank, idx=1725, count=64
# Add blank, idx=1735, count=65
# Add blank, idx=1754, count=66
# Add blank, idx=1785, count=67
# Add blank, idx=1857, count=68
# Add blank, idx=1868, count=69
# Add blank, idx=1880, count=70
# Add blank, idx=1896, count=71
# Add blank, idx=1953, count=72
# Add blank, idx=1958, count=73
# Add blank, idx=2013, count=74
# Add blank, idx=2022, count=75
# Add blank, idx=2025, count=76
# Add blank, idx=2050, count=77
# Add blank, idx=2066, count=78
# Add blank, idx=2067, count=79
# Add blank, idx=2076, count=80
# Add blank, idx=2092, count=81
# Add blank, idx=2096, count=82
# Add blank, idx=2129, count=83
# Add blank, idx=2161, count=84
# Add blank, idx=2169, count=85
# Add blank, idx=2241, count=86
# Add blank, idx=2251, count=87
# Add blank, idx=2295, count=88
# Add blank, idx=2298, count=89
# Add blank, idx=2305, count=90
# Add blank, idx=2326, count=91
# Add blank, idx=2374, count=92
# Add blank, idx=2380, count=93
# Add blank, idx=2396, count=94
# Add blank, idx=2412, count=95
# Add blank, idx=2431, count=96
# Add blank, idx=2489, count=97
# Add blank, idx=2494, count=98
# Add blank, idx=2499, count=99
# Add blank, idx=2515, count=100
# Add blank, idx=2527, count=101
# Add blank, idx=2541, count=102
# Add blank, idx=2564, count=103
# Add blank, idx=2592, count=104
# Add blank, idx=2611, count=105
# Add blank, idx=2628, count=106
# Add blank, idx=2654, count=107
# Add blank, idx=2664, count=108
# Add blank, idx=2669, count=109
# Add blank, idx=2685, count=110
# Add blank, idx=2704, count=111
# Add blank, idx=2778, count=112
# Add blank, idx=2873, count=113
# Add blank, idx=2895, count=114
# Add blank, idx=3007, count=115
# Add blank, idx=3028, count=116
# Add blank, idx=3031, count=117
# Add blank, idx=3041, count=118
# Add blank, idx=3043, count=119
# Add blank, idx=3045, count=120
# Add blank, idx=3059, count=121
# Add blank, idx=3213, count=122
# Add blank, idx=3224, count=123
# Add blank, idx=3269, count=124
# Add blank, idx=3317, count=125
# Add blank, idx=3348, count=126
# Add blank, idx=3379, count=127
# Add blank, idx=3417, count=128
# Add blank, idx=3505, count=129
# Add blank, idx=3509, count=130
# Add blank, idx=3533, count=131
# Add blank, idx=3543, count=132
# Add blank, idx=3596, count=133
# Add blank, idx=3601, count=134
# Add blank, idx=3610, count=135
# Add blank, idx=3614, count=136
# Add blank, idx=3616, count=137
# Add blank, idx=3618, count=138
# Add blank, idx=3711, count=139
# Add blank, idx=3725, count=140
# Add blank, idx=3740, count=141
# Add blank, idx=3751, count=142
# Add blank, idx=3763, count=143
# Add blank, idx=3769, count=144
# Add blank, idx=3801, count=145
# Add blank, idx=3818, count=146
# Add blank, idx=3833, count=147
# Add blank, idx=3834, count=148
# Add blank, idx=3843, count=149
# Add blank, idx=3859, count=150
# Add blank, idx=3920, count=151
# Add blank, idx=3937, count=152
# Add blank, idx=3950, count=153
# Add blank, idx=3987, count=154
# Add blank, idx=3999, count=155
# Add blank, idx=4009, count=156
# Add blank, idx=4027, count=157
# Add blank, idx=4043, count=158
# Add blank, idx=4047, count=159
# Add blank, idx=4058, count=160
# Add blank, idx=4112, count=161
# Add blank, idx=4120, count=162
# Add blank, idx=4178, count=163
# Add blank, idx=4182, count=164
# Add blank, idx=4195, count=165
# Add blank, idx=4248, count=166
# Add blank, idx=4266, count=167
# Add blank, idx=4269, count=168
# Add blank, idx=4291, count=169
# Add blank, idx=4300, count=170
# Add blank, idx=4317, count=171
# Add blank, idx=4336, count=172
# Add blank, idx=4352, count=173
# Add blank, idx=4374, count=174
# Add blank, idx=4401, count=175
# Add blank, idx=4404, count=176
# Add blank, idx=4418, count=177
# Add blank, idx=4427, count=178
# Add blank, idx=4429, count=179
# Add blank, idx=4446, count=180
# Add blank, idx=4487, count=181
# Add blank, idx=4501, count=182
# Add blank, idx=4588, count=183
# Add blank, idx=4591, count=184
# Add blank, idx=4592, count=185
# Add blank, idx=4670, count=186
# Add blank, idx=4682, count=187
# Add blank, idx=4753, count=188
# Add blank, idx=4775, count=189
# Add blank, idx=4868, count=190
# Add blank, idx=4874, count=191
# Add blank, idx=4877, count=192
# Add blank, idx=4913, count=193
# Add blank, idx=4914, count=194
# Add blank, idx=4916, count=195
# Add blank, idx=4933, count=196
# Add blank, idx=4970, count=197
# Add blank, idx=4983, count=198
# Add blank, idx=5001, count=199
# Add blank, idx=5008, count=200
# Add blank, idx=5025, count=201
# Add blank, idx=5039, count=202
# Add blank, idx=5050, count=203
# Add blank, idx=5152, count=204
# Add blank, idx=5174, count=205
# Add blank, idx=5211, count=206
# Add blank, idx=5215, count=207
# Add blank, idx=5233, count=208
# Add blank, idx=5259, count=209
# Add blank, idx=5264, count=210
# Add blank, idx=5281, count=211
# Add blank, idx=5289, count=212
# Add blank, idx=5322, count=213
# Add blank, idx=5327, count=214
# Add blank, idx=5370, count=215
# Add blank, idx=5379, count=216
# Add blank, idx=5389, count=217
# Add blank, idx=5402, count=218
# Add blank, idx=5420, count=219
# Add blank, idx=5439, count=220
# Add blank, idx=5477, count=221
# Add blank, idx=5483, count=222
# Add blank, idx=5501, count=223
# Add blank, idx=5502, count=224
# Add blank, idx=5537, count=225
# Add blank, idx=5545, count=226
# Add blank, idx=5557, count=227
# Add blank, idx=5566, count=228
# Add blank, idx=5605, count=229
# Add blank, idx=5615, count=230
# Add blank, idx=5628, count=231
# Add blank, idx=5638, count=232
# Add blank, idx=5671, count=233
# Add blank, idx=5742, count=234
# Add blank, idx=5754, count=235
# Add blank, idx=5761, count=236
# Add blank, idx=5770, count=237
# Add blank, idx=5780, count=238
# Add blank, idx=5855, count=239
# Add blank, idx=5874, count=240
# Add blank, idx=5881, count=241
# Add blank, idx=5915, count=242
# Add blank, idx=5935, count=243
# Add blank, idx=5943, count=244
# Add blank, idx=5954, count=245
# (965, 11, 160, 160) (965, 1, 160, 160) inf -3901.0 1.0 0.0
# /usr/local/lib/python3.4/dist-packages/scipy/misc/pilutil.py:101: RuntimeWarning: invalid value encountered in multiply
#   bytedata = (data - cmin) * scale + low
# Training data shapes:
# (965, 11, 160, 160)
# (965, 1, 160, 160)

# %%
mkdir_p("visualise/val")
mkdir_p("visualise/val/ndvi")
mkdir_p("visualise/val/savi")
mkdir_p("visualise/val/evi")

for i in range(x_val.shape[0]):
    save_visual_img_patch(x_val, "val", sample_idx=i)
    save_visual_img_patch(x_val, "val/ndvi", sample_idx=i, band=8)
    save_visual_img_patch(x_val, "val/savi", sample_idx=i, band=9)
    save_visual_img_patch(x_val, "val/evi", sample_idx=i, band=10)
    save_visual_msk_patch(y_val, "val", sample_idx=i)

print("Validation data shapes:")
print(x_val.shape)
print(y_val.shape)
# Out:
# /usr/local/lib/python3.4/dist-packages/scipy/misc/pilutil.py:101: RuntimeWarning: invalid value encountered in multiply
#   bytedata = (data - cmin) * scale + low
# /usr/local/lib/python3.4/dist-packages/scipy/misc/pilutil.py:101: RuntimeWarning: invalid value encountered in subtract
#   bytedata = (data - cmin) * scale + low
# Validation data shapes:
# (726, 11, 160, 160)
# (726, 1, 160, 160)

# %% [markdown]
# SAVI and NDVI yield very similar images - indeed the calucation is almost the same. Remove (the more complication/involved) SAVI computation.

# %% [markdown]
# Lets review all bands to see if any in particular highlight the trees well.

# %%
folder_names = ["trn/0/",
                "trn/1/",
                "trn/2/",
                "trn/3/",
                "trn/4/",
                "trn/5/",
                "trn/6/",
                "trn/7/",
                "trn/ndvi/",
                "trn/savi/",
                "trn/evi/"]

x_trn, y_trn = get_patches(img, msk, amt=6000, aug=False)
for i in range(x_trn.shape[0]):
    for band_idx, folder_name in enumerate(folder_names):
        mkdir_p("visualise/"+folder_name)        
        
        save_visual_img_patch(x_trn, folder_name, sample_idx=i, band=band_idx)
    
print("Training data shapes:")
print(x_trn.shape)
folder_name = "trn/msk/"
mkdir_p("visualise/"+folder_name)        print(y_trn.shape)
# Out:
# Add blank, idx=41, count=1
# Add blank, idx=89, count=2
# Add blank, idx=115, count=3
# Add blank, idx=118, count=4
# Add blank, idx=124, count=5
# Add blank, idx=138, count=6
# Add blank, idx=178, count=7
# Add blank, idx=182, count=8
# Add blank, idx=223, count=9
# Add blank, idx=231, count=10
# Add blank, idx=276, count=11
# Add blank, idx=296, count=12
# Add blank, idx=321, count=13
# Add blank, idx=329, count=14
# Add blank, idx=342, count=15
# Add blank, idx=370, count=16
# Add blank, idx=389, count=17
# Add blank, idx=475, count=18
# Add blank, idx=481, count=19
# Add blank, idx=498, count=20
# Add blank, idx=535, count=21
# Add blank, idx=553, count=22
# Add blank, idx=566, count=23
# Add blank, idx=590, count=24
# Add blank, idx=594, count=25
# Add blank, idx=595, count=26
# Add blank, idx=616, count=27
# Add blank, idx=629, count=28
# Add blank, idx=662, count=29
# Add blank, idx=734, count=30
# Add blank, idx=741, count=31
# Add blank, idx=749, count=32
# Add blank, idx=771, count=33
# Add blank, idx=796, count=34
# Add blank, idx=820, count=35
# Add blank, idx=907, count=36
# Add blank, idx=918, count=37
# Add blank, idx=924, count=38
# Add blank, idx=956, count=39
# Add blank, idx=979, count=40
# Add blank, idx=988, count=41
# Add blank, idx=990, count=42
# Add blank, idx=1006, count=43
# Add blank, idx=1007, count=44
# Add blank, idx=1019, count=45
# Add blank, idx=1051, count=46
# Add blank, idx=1061, count=47
# Add blank, idx=1062, count=48
# Add blank, idx=1095, count=49
# Add blank, idx=1100, count=50
# Add blank, idx=1110, count=51
# Add blank, idx=1126, count=52
# Add blank, idx=1197, count=53
# Add blank, idx=1251, count=54
# Add blank, idx=1292, count=55
# Add blank, idx=1296, count=56
# Add blank, idx=1297, count=57
# Add blank, idx=1301, count=58
# Add blank, idx=1348, count=59
# Add blank, idx=1384, count=60
# Add blank, idx=1396, count=61
# Add blank, idx=1418, count=62
# Add blank, idx=1424, count=63
# Add blank, idx=1454, count=64
# Add blank, idx=1480, count=65
# Add blank, idx=1489, count=66
# Add blank, idx=1499, count=67
# Add blank, idx=1502, count=68
# Add blank, idx=1521, count=69
# Add blank, idx=1525, count=70
# Add blank, idx=1540, count=71
# Add blank, idx=1546, count=72
# Add blank, idx=1595, count=73
# Add blank, idx=1601, count=74
# Add blank, idx=1610, count=75
# Add blank, idx=1611, count=76
# Add blank, idx=1673, count=77
# Add blank, idx=1695, count=78
# Add blank, idx=1699, count=79
# Add blank, idx=1746, count=80
# Add blank, idx=1772, count=81
# Add blank, idx=1792, count=82
# Add blank, idx=1793, count=83
# Add blank, idx=1837, count=84
# Add blank, idx=1851, count=85
# Add blank, idx=1866, count=86
# Add blank, idx=1869, count=87
# Add blank, idx=1895, count=88
# Add blank, idx=1913, count=89
# Add blank, idx=1951, count=90
# Add blank, idx=1954, count=91
# Add blank, idx=1960, count=92
# Add blank, idx=1967, count=93
# Add blank, idx=1979, count=94
# Add blank, idx=1982, count=95
# Add blank, idx=1999, count=96
# Add blank, idx=2002, count=97
# Add blank, idx=2007, count=98
# Add blank, idx=2042, count=99
# Add blank, idx=2072, count=100
# Add blank, idx=2157, count=101
# Add blank, idx=2158, count=102
# Add blank, idx=2164, count=103
# Add blank, idx=2204, count=104
# Add blank, idx=2224, count=105
# Add blank, idx=2232, count=106
# Add blank, idx=2236, count=107
# Add blank, idx=2244, count=108
# Add blank, idx=2268, count=109
# Add blank, idx=2270, count=110
# Add blank, idx=2274, count=111
# Add blank, idx=2294, count=112
# Add blank, idx=2330, count=113
# Add blank, idx=2371, count=114
# Add blank, idx=2390, count=115
# Add blank, idx=2436, count=116
# Add blank, idx=2443, count=117
# Add blank, idx=2473, count=118
# Add blank, idx=2502, count=119
# Add blank, idx=2508, count=120
# Add blank, idx=2528, count=121
# Add blank, idx=2547, count=122
# Add blank, idx=2554, count=123
# Add blank, idx=2568, count=124
# Add blank, idx=2578, count=125
# Add blank, idx=2590, count=126
# Add blank, idx=2616, count=127
# Add blank, idx=2620, count=128
# Add blank, idx=2628, count=129
# Add blank, idx=2674, count=130
# Add blank, idx=2691, count=131
# Add blank, idx=2695, count=132
# Add blank, idx=2730, count=133
# Add blank, idx=2745, count=134
# Add blank, idx=2785, count=135
# Add blank, idx=2808, count=136
# Add blank, idx=2880, count=137
# Add blank, idx=2882, count=138
# Add blank, idx=2887, count=139
# Add blank, idx=2900, count=140
# Add blank, idx=2915, count=141
# Add blank, idx=2929, count=142
# Add blank, idx=2943, count=143
# Add blank, idx=2987, count=144
# Add blank, idx=3020, count=145
# Add blank, idx=3043, count=146
# Add blank, idx=3054, count=147
# Add blank, idx=3089, count=148
# Add blank, idx=3141, count=149
# Add blank, idx=3144, count=150
# Add blank, idx=3160, count=151
# Add blank, idx=3166, count=152
# Add blank, idx=3170, count=153
# Add blank, idx=3201, count=154
# Add blank, idx=3204, count=155
# Add blank, idx=3219, count=156
# Add blank, idx=3262, count=157
# Add blank, idx=3294, count=158
# Add blank, idx=3336, count=159
# Add blank, idx=3347, count=160
# Add blank, idx=3354, count=161
# Add blank, idx=3373, count=162
# Add blank, idx=3383, count=163
# Add blank, idx=3391, count=164
# Add blank, idx=3423, count=165
# Add blank, idx=3425, count=166
# Add blank, idx=3447, count=167
# Add blank, idx=3495, count=168
# Add blank, idx=3502, count=169
# Add blank, idx=3561, count=170
# Add blank, idx=3577, count=171
# Add blank, idx=3579, count=172
# Add blank, idx=3682, count=173
# Add blank, idx=3683, count=174
# Add blank, idx=3730, count=175
# Add blank, idx=3765, count=176
# Add blank, idx=3777, count=177
# Add blank, idx=3800, count=178
# Add blank, idx=3802, count=179
# Add blank, idx=3810, count=180
# Add blank, idx=3830, count=181
# Add blank, idx=3855, count=182
# Add blank, idx=3888, count=183
# Add blank, idx=3926, count=184
# Add blank, idx=3928, count=185
# Add blank, idx=3938, count=186
# Add blank, idx=3958, count=187
# Add blank, idx=3959, count=188
# Add blank, idx=3974, count=189
# Add blank, idx=4059, count=190
# Add blank, idx=4099, count=191
# Add blank, idx=4121, count=192
# Add blank, idx=4125, count=193
# Add blank, idx=4132, count=194
# Add blank, idx=4148, count=195
# Add blank, idx=4156, count=196
# Add blank, idx=4197, count=197
# Add blank, idx=4200, count=198
# Add blank, idx=4202, count=199
# Add blank, idx=4219, count=200
# Add blank, idx=4265, count=201
# Add blank, idx=4270, count=202
# Add blank, idx=4281, count=203
# Add blank, idx=4289, count=204
# Add blank, idx=4347, count=205
# Add blank, idx=4367, count=206
# Add blank, idx=4377, count=207
# Add blank, idx=4401, count=208
# Add blank, idx=4415, count=209
# Add blank, idx=4434, count=210
# Add blank, idx=4449, count=211
# Add blank, idx=4450, count=212
# Add blank, idx=4451, count=213
# Add blank, idx=4460, count=214
# Add blank, idx=4473, count=215
# Add blank, idx=4534, count=216
# Add blank, idx=4568, count=217
# Add blank, idx=4577, count=218
# Add blank, idx=4607, count=219
# Add blank, idx=4665, count=220
# Add blank, idx=4731, count=221
# Add blank, idx=4769, count=222
# Add blank, idx=4787, count=223
# Add blank, idx=4794, count=224
# Add blank, idx=4840, count=225
# Add blank, idx=4846, count=226
# Add blank, idx=4892, count=227
# Add blank, idx=4898, count=228
# Add blank, idx=4903, count=229
# Add blank, idx=4908, count=230
# Add blank, idx=4922, count=231
# Add blank, idx=4973, count=232
# Add blank, idx=5005, count=233
# Add blank, idx=5009, count=234
# Add blank, idx=5012, count=235
# Add blank, idx=5021, count=236
# Add blank, idx=5045, count=237
# Add blank, idx=5047, count=238
# Add blank, idx=5055, count=239
# Add blank, idx=5094, count=240
# Add blank, idx=5095, count=241
# Add blank, idx=5101, count=242
# Add blank, idx=5134, count=243
# Add blank, idx=5148, count=244
# Add blank, idx=5206, count=245
# Add blank, idx=5208, count=246
# Add blank, idx=5209, count=247
# Add blank, idx=5221, count=248
# Add blank, idx=5228, count=249
# Add blank, idx=5241, count=250
# Add blank, idx=5263, count=251
# Add blank, idx=5309, count=252
# Add blank, idx=5323, count=253
# Add blank, idx=5335, count=254
# Add blank, idx=5340, count=255
# Add blank, idx=5342, count=256
# Add blank, idx=5347, count=257
# Add blank, idx=5389, count=258
# Add blank, idx=5419, count=259
# Add blank, idx=5427, count=260
# Add blank, idx=5438, count=261
# Add blank, idx=5484, count=262
# Add blank, idx=5494, count=263
# Add blank, idx=5520, count=264
# Add blank, idx=5541, count=265
# Add blank, idx=5585, count=266
# Add blank, idx=5588, count=267
# Add blank, idx=5629, count=268
# Add blank, idx=5633, count=269
# Add blank, idx=5647, count=270
# Add blank, idx=5649, count=271
# Add blank, idx=5650, count=272
# Add blank, idx=5675, count=273
# Add blank, idx=5733, count=274
# Add blank, idx=5774, count=275
# Add blank, idx=5783, count=276
# Add blank, idx=5790, count=277
# Add blank, idx=5798, count=278
# Add blank, idx=5802, count=279
# Add blank, idx=5827, count=280
# Add blank, idx=5853, count=281
# Add blank, idx=5888, count=282
# Add blank, idx=5905, count=283
# Add blank, idx=5906, count=284
# Add blank, idx=5943, count=285
# Add blank, idx=5980, count=286
# (933, 11, 160, 160) (933, 1, 160, 160) inf -3901.0 1.0 0.0
# /usr/local/lib/python3.4/dist-packages/scipy/misc/pilutil.py:101: RuntimeWarning: invalid value encountered in multiply
#   bytedata = (data - cmin) * scale + low
# Training data shapes:
# (933, 11, 160, 160)
# (933, 1, 160, 160)

# %%
folder_name = "trn/msk/"
mkdir_p("visualise/"+folder_name)

for i in range(y_trn.shape[0]):
    save_visual_msk_patch(y_trn, folder_name, sample_idx=i)

# %%
folder_names = ["val/0/",
                "val/1/",
                "val/2/",
                "val/3/",
                "val/4/",
                "val/5/",
                "val/6/",
                "val/7/",
                "val/ndvi/",
                "val/savi/",
                "val/evi/"]

for i in range(x_val.shape[0]):
    for band_idx, folder_name in enumerate(folder_names):
        mkdir_p("visualise/"+folder_name)        
        
        save_visual_img_patch(x_val, folder_name, sample_idx=i, band=band_idx)
# Out:
# /usr/local/lib/python3.4/dist-packages/scipy/misc/pilutil.py:101: RuntimeWarning: invalid value encountered in multiply
#   bytedata = (data - cmin) * scale + low
# /usr/local/lib/python3.4/dist-packages/scipy/misc/pilutil.py:101: RuntimeWarning: invalid value encountered in subtract
#   bytedata = (data - cmin) * scale + low

# %%
mkdir_p("visualise/val/msk/")

for i in range(y_val.shape[0]):        
    save_visual_msk_patch(y_val, "val/msk/", sample_idx=i)

# %% [markdown]
# From a random set of images, for distinguishing trees the bands **3,4,5,ndvi,evi** appeared visually best.

# %% [markdown]
# Looking at the kensu blog on the competition, RGB and P bands look quite useful for detecting trees also - https://viewer.kensu.io/notebooks/Geotrellis/DSTL-LEARNING.snb?read_only=1. (NOTE: It could be that the RGB was created from the P with pan-sharpening - hence we'll also train a model with just the P.)

# %% [markdown]
# ## Recreating data for bands of interest

# %%
def make_val(aug=False):
    print("let's pick some samples for validation")
    img = np.load(inDir + '/data/x_valALL_%d.npy' % N_Cls)
    msk = np.load(inDir + '/data/y_valALL_%d.npy' % N_Cls)
    x, y = get_patches(img, msk, amt=3000, aug=aug)  # amt := attempt (maybe - i.e. attempting to create 3000 patches, without
                                            # percentage area cover threshold.

    print("Validation data shapes:")
    print(x.shape)
    print(y.shape)

    np.save(inDir + '/data/x_val_%d' % N_Cls, x)
    np.save(inDir + '/data/y_val_%d' % N_Cls, y)
    
    
def stick_all_train():
    print("let's stick all imgs together")
    s = 835  # size of the M images (roughly)

    # 25 training images grid
    x = np.zeros((5 * s, 4 * s, 5))      # (3,4,5,ndvi,evi)
    y = np.zeros((5 * s, 4 * s, N_Cls))  # axis=2 denote the class label

    ids = sorted(DF.ImageId.unique())
    print(len(ids))
    
    
    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(4):
            id = ids[1 * i + j]

            img = M(id)
        
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            
            # Add indexes found visually to be useful
            x[s * i:s * i + s, s * j:s * j + s, 0] = img[:s, :s, 3]
            x[s * i:s * i + s, s * j:s * j + s, 1] = img[:s, :s, 4]
            x[s * i:s * i + s, s * j:s * j + s, 2] = img[:s, :s, 5]
            ndvi, savi, evi = create_indexes(id)
            x[s * i:s * i + s, s * j:s * j + s, 3] = ndvi[:s, :s]
            x[s * i:s * i + s, s * j:s * j + s, 4] = evi[:s, :s]
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1)[:s, :s]
    
    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))
    
    np.save(inDir + '/data/x_trn_%d' % N_Cls, x)
    np.save(inDir + '/data/y_trn_%d' % N_Cls, y)
    
    
def stick_all_val():
    print("let's stick all imgs together")
    s = 835  # size of the M images

    # 25 training images grid
    x = np.zeros((5 * s, 1 * s, 5))      # (3,4,5,ndvi,evi)
    y = np.zeros((5 * s, 1 * s, N_Cls))   # axis=2 denote the class label

    ids = sorted(val_DF.ImageId.unique())
    print(len(ids))

    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(1):
            id = ids[1 * i + j]

            img = M(id)
            
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            
            # Add indexes found visually to be useful
            x[s * i:s * i + s, s * j:s * j + s, 0] = img[:s, :s, 3]
            x[s * i:s * i + s, s * j:s * j + s, 1] = img[:s, :s, 4]
            x[s * i:s * i + s, s * j:s * j + s, 2] = img[:s, :s, 5]
            ndvi, savi, evi = create_indexes(id)
            x[s * i:s * i + s, s * j:s * j + s, 3] = ndvi[:s, :s]
            x[s * i:s * i + s, s * j:s * j + s, 4] = evi[:s, :s]
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1, wkt_list_pandas=val_DF)[:s, :s]

    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))

    np.save(inDir + '/data/x_valALL_%d' % N_Cls, x)
    np.save(inDir + '/data/y_valALL_%d' % N_Cls, y)

# %%
stick_all_train()

stick_all_val()
make_val()
# Out:
# let's stick all imgs together
# 20
# (837, 849, 8) 6010_1_2 1.0 0.0
# (837, 849, 8) 6010_4_2 1.0 0.0
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in true_divide
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 849, 8) 6010_4_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 851, 8) 6060_2_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 851, 8) 6060_2_3 1.0 0.0
# (837, 848, 8) 6090_2_0 1.0 0.0
# x shape is:
# (4175, 3340, 5)
# y shape is:
# (4175, 3340, 1)
# 1.0 0.0
# let's stick all imgs together
# 5
# (837, 848, 8) 6010_4_4 1.0 0.0
# (838, 835, 8) 6070_2_3 1.0 0.0
# (837, 848, 8) 6100_2_3 1.0 0.0
# (837, 849, 8) 6110_4_0 1.0 0.0
# (837, 849, 8) 6140_1_2 1.0 0.0
# x shape is:
# (4175, 835, 5)
# y shape is:
# (4175, 835, 1)
# 1.0 0.0
# let's pick some samples for validation
# Add blank, idx=37, count=1
# Add blank, idx=38, count=2
# Add blank, idx=39, count=3
# Add blank, idx=48, count=4
# Add blank, idx=50, count=5
# Add blank, idx=52, count=6
# Add blank, idx=64, count=7
# Add blank, idx=69, count=8
# Add blank, idx=80, count=9
# Add blank, idx=83, count=10
# Add blank, idx=84, count=11
# Add blank, idx=100, count=12
# Add blank, idx=117, count=13
# Add blank, idx=126, count=14
# Add blank, idx=128, count=15
# Add blank, idx=130, count=16
# Add blank, idx=142, count=17
# Add blank, idx=150, count=18
# Add blank, idx=156, count=19
# Add blank, idx=170, count=20
# Add blank, idx=172, count=21
# Add blank, idx=186, count=22
# Add blank, idx=188, count=23
# Add blank, idx=189, count=24
# Add blank, idx=193, count=25
# Add blank, idx=196, count=26
# Add blank, idx=210, count=27
# Add blank, idx=211, count=28
# Add blank, idx=214, count=29
# Add blank, idx=224, count=30
# Add blank, idx=240, count=31
# Add blank, idx=250, count=32
# Add blank, idx=266, count=33
# Add blank, idx=270, count=34
# Add blank, idx=277, count=35
# Add blank, idx=306, count=36
# Add blank, idx=321, count=37
# Add blank, idx=331, count=38
# Add blank, idx=339, count=39
# Add blank, idx=342, count=40
# Add blank, idx=345, count=41
# Add blank, idx=353, count=42
# Add blank, idx=355, count=43
# Add blank, idx=386, count=44
# Add blank, idx=392, count=45
# Add blank, idx=400, count=46
# Add blank, idx=403, count=47
# Add blank, idx=405, count=48
# Add blank, idx=407, count=49
# Add blank, idx=408, count=50
# Add blank, idx=409, count=51
# Add blank, idx=419, count=52
# Add blank, idx=421, count=53
# Add blank, idx=433, count=54
# Add blank, idx=455, count=55
# Add blank, idx=467, count=56
# Add blank, idx=496, count=57
# Add blank, idx=512, count=58
# Add blank, idx=515, count=59
# Add blank, idx=520, count=60
# Add blank, idx=537, count=61
# Add blank, idx=547, count=62
# Add blank, idx=549, count=63
# Add blank, idx=556, count=64
# Add blank, idx=569, count=65
# Add blank, idx=578, count=66
# Add blank, idx=580, count=67
# Add blank, idx=587, count=68
# Add blank, idx=591, count=69
# Add blank, idx=609, count=70
# Add blank, idx=615, count=71
# Add blank, idx=620, count=72
# Add blank, idx=644, count=73
# Add blank, idx=689, count=74
# Add blank, idx=690, count=75
# Add blank, idx=691, count=76
# Add blank, idx=692, count=77
# Add blank, idx=699, count=78
# Add blank, idx=705, count=79
# Add blank, idx=710, count=80
# Add blank, idx=722, count=81
# Add blank, idx=735, count=82
# Add blank, idx=754, count=83
# Add blank, idx=770, count=84
# Add blank, idx=773, count=85
# Add blank, idx=774, count=86
# Add blank, idx=787, count=87
# Add blank, idx=788, count=88
# Add blank, idx=798, count=89
# Add blank, idx=821, count=90
# Add blank, idx=836, count=91
# Add blank, idx=842, count=92
# Add blank, idx=856, count=93
# Add blank, idx=870, count=94
# Add blank, idx=872, count=95
# Add blank, idx=883, count=96
# Add blank, idx=884, count=97
# Add blank, idx=892, count=98
# Add blank, idx=895, count=99
# Add blank, idx=902, count=100
# Add blank, idx=916, count=101
# Add blank, idx=917, count=102
# Add blank, idx=926, count=103
# Add blank, idx=934, count=104
# Add blank, idx=939, count=105
# Add blank, idx=953, count=106
# Add blank, idx=968, count=107
# Add blank, idx=971, count=108
# Add blank, idx=974, count=109
# Add blank, idx=976, count=110
# Add blank, idx=978, count=111
# Add blank, idx=981, count=112
# Add blank, idx=985, count=113
# Add blank, idx=988, count=114
# Add blank, idx=995, count=115
# Add blank, idx=1004, count=116
# Add blank, idx=1010, count=117
# Add blank, idx=1025, count=118
# Add blank, idx=1026, count=119
# Add blank, idx=1029, count=120
# Add blank, idx=1031, count=121
# Add blank, idx=1049, count=122
# Add blank, idx=1051, count=123
# Add blank, idx=1052, count=124
# Add blank, idx=1053, count=125
# Add blank, idx=1068, count=126
# Add blank, idx=1080, count=127
# Add blank, idx=1082, count=128
# Add blank, idx=1083, count=129
# Add blank, idx=1085, count=130
# Add blank, idx=1088, count=131
# Add blank, idx=1122, count=132
# Add blank, idx=1129, count=133
# Add blank, idx=1133, count=134
# Add blank, idx=1139, count=135
# Add blank, idx=1141, count=136
# Add blank, idx=1146, count=137
# Add blank, idx=1154, count=138
# Add blank, idx=1157, count=139
# Add blank, idx=1164, count=140
# Add blank, idx=1176, count=141
# Add blank, idx=1182, count=142
# Add blank, idx=1211, count=143
# Add blank, idx=1214, count=144
# Add blank, idx=1220, count=145
# Add blank, idx=1223, count=146
# Add blank, idx=1224, count=147
# Add blank, idx=1236, count=148
# Add blank, idx=1240, count=149
# Add blank, idx=1249, count=150
# Add blank, idx=1251, count=151
# Add blank, idx=1254, count=152
# Add blank, idx=1260, count=153
# Add blank, idx=1264, count=154
# Add blank, idx=1269, count=155
# Add blank, idx=1276, count=156
# Add blank, idx=1281, count=157
# Add blank, idx=1289, count=158
# Add blank, idx=1298, count=159
# Add blank, idx=1331, count=160
# Add blank, idx=1335, count=161
# Add blank, idx=1342, count=162
# Add blank, idx=1344, count=163
# Add blank, idx=1349, count=164
# Add blank, idx=1371, count=165
# Add blank, idx=1373, count=166
# Add blank, idx=1374, count=167
# Add blank, idx=1378, count=168
# Add blank, idx=1388, count=169
# Add blank, idx=1394, count=170
# Add blank, idx=1402, count=171
# Add blank, idx=1407, count=172
# Add blank, idx=1421, count=173
# Add blank, idx=1429, count=174
# Add blank, idx=1430, count=175
# Add blank, idx=1437, count=176
# Add blank, idx=1441, count=177
# Add blank, idx=1442, count=178
# Add blank, idx=1450, count=179
# Add blank, idx=1473, count=180
# Add blank, idx=1474, count=181
# Add blank, idx=1477, count=182
# Add blank, idx=1483, count=183
# Add blank, idx=1486, count=184
# Add blank, idx=1492, count=185
# Add blank, idx=1495, count=186
# Add blank, idx=1515, count=187
# Add blank, idx=1521, count=188
# Add blank, idx=1522, count=189
# Add blank, idx=1540, count=190
# Add blank, idx=1554, count=191
# Add blank, idx=1606, count=192
# Add blank, idx=1612, count=193
# Add blank, idx=1614, count=194
# Add blank, idx=1626, count=195
# Add blank, idx=1640, count=196
# Add blank, idx=1642, count=197
# Add blank, idx=1644, count=198
# Add blank, idx=1646, count=199
# Add blank, idx=1652, count=200
# Add blank, idx=1667, count=201
# Add blank, idx=1687, count=202
# Add blank, idx=1691, count=203
# Add blank, idx=1701, count=204
# Add blank, idx=1732, count=205
# Add blank, idx=1737, count=206
# Add blank, idx=1741, count=207
# Add blank, idx=1743, count=208
# Add blank, idx=1747, count=209
# Add blank, idx=1758, count=210
# Add blank, idx=1773, count=211
# Add blank, idx=1777, count=212
# Add blank, idx=1780, count=213
# Add blank, idx=1784, count=214
# Add blank, idx=1787, count=215
# Add blank, idx=1804, count=216
# Add blank, idx=1813, count=217
# Add blank, idx=1832, count=218
# Add blank, idx=1835, count=219
# Add blank, idx=1842, count=220
# Add blank, idx=1843, count=221
# Add blank, idx=1854, count=222
# Add blank, idx=1860, count=223
# Add blank, idx=1864, count=224
# Add blank, idx=1871, count=225
# Add blank, idx=1873, count=226
# Add blank, idx=1881, count=227
# Add blank, idx=1898, count=228
# Add blank, idx=1900, count=229
# Add blank, idx=1908, count=230
# Add blank, idx=1920, count=231
# Add blank, idx=1938, count=232
# Add blank, idx=1939, count=233
# Add blank, idx=1959, count=234
# Add blank, idx=1960, count=235
# Add blank, idx=1968, count=236
# Add blank, idx=1970, count=237
# Add blank, idx=1984, count=238
# Add blank, idx=1997, count=239
# Add blank, idx=2006, count=240
# Add blank, idx=2009, count=241
# Add blank, idx=2014, count=242
# Add blank, idx=2048, count=243
# Add blank, idx=2052, count=244
# Add blank, idx=2066, count=245
# Add blank, idx=2089, count=246
# Add blank, idx=2098, count=247
# Add blank, idx=2101, count=248
# Add blank, idx=2122, count=249
# Add blank, idx=2125, count=250
# Add blank, idx=2131, count=251
# Add blank, idx=2132, count=252
# Add blank, idx=2149, count=253
# Add blank, idx=2151, count=254
# Add blank, idx=2156, count=255
# Add blank, idx=2157, count=256
# Add blank, idx=2162, count=257
# Add blank, idx=2181, count=258
# Add blank, idx=2182, count=259
# Add blank, idx=2196, count=260
# Add blank, idx=2209, count=261
# Add blank, idx=2228, count=262
# Add blank, idx=2235, count=263
# Add blank, idx=2240, count=264
# Add blank, idx=2241, count=265
# Add blank, idx=2277, count=266
# Add blank, idx=2288, count=267
# Add blank, idx=2314, count=268
# Add blank, idx=2328, count=269
# Add blank, idx=2331, count=270
# Add blank, idx=2345, count=271
# Add blank, idx=2347, count=272
# Add blank, idx=2360, count=273
# Add blank, idx=2363, count=274
# Add blank, idx=2369, count=275
# Add blank, idx=2371, count=276
# Add blank, idx=2384, count=277
# Add blank, idx=2386, count=278
# Add blank, idx=2398, count=279
# Add blank, idx=2406, count=280
# Add blank, idx=2414, count=281
# Add blank, idx=2435, count=282
# Add blank, idx=2443, count=283
# Add blank, idx=2445, count=284
# Add blank, idx=2470, count=285
# Add blank, idx=2471, count=286
# Add blank, idx=2475, count=287
# Add blank, idx=2486, count=288
# Add blank, idx=2505, count=289
# Add blank, idx=2516, count=290
# Add blank, idx=2518, count=291
# Add blank, idx=2521, count=292
# Add blank, idx=2528, count=293
# Add blank, idx=2534, count=294
# Add blank, idx=2535, count=295
# Add blank, idx=2536, count=296
# Add blank, idx=2555, count=297
# Add blank, idx=2561, count=298
# Add blank, idx=2573, count=299
# Add blank, idx=2588, count=300
# Add blank, idx=2591, count=301
# Add blank, idx=2598, count=302
# Add blank, idx=2603, count=303
# Add blank, idx=2611, count=304
# Add blank, idx=2618, count=305
# Add blank, idx=2626, count=306
# Add blank, idx=2632, count=307
# Add blank, idx=2638, count=308
# Add blank, idx=2641, count=309
# Add blank, idx=2646, count=310
# Add blank, idx=2654, count=311
# Add blank, idx=2663, count=312
# Add blank, idx=2670, count=313
# Add blank, idx=2672, count=314
# Add blank, idx=2673, count=315
# Add blank, idx=2704, count=316
# Add blank, idx=2712, count=317
# Add blank, idx=2716, count=318
# Add blank, idx=2724, count=319
# Add blank, idx=2727, count=320
# Add blank, idx=2736, count=321
# Add blank, idx=2746, count=322
# Add blank, idx=2755, count=323
# Add blank, idx=2760, count=324
# Add blank, idx=2781, count=325
# Add blank, idx=2785, count=326
# Add blank, idx=2786, count=327
# Add blank, idx=2795, count=328
# Add blank, idx=2812, count=329
# Add blank, idx=2817, count=330
# Add blank, idx=2820, count=331
# Add blank, idx=2822, count=332
# Add blank, idx=2824, count=333
# Add blank, idx=2828, count=334
# Add blank, idx=2844, count=335
# Add blank, idx=2885, count=336
# Add blank, idx=2886, count=337
# Add blank, idx=2898, count=338
# Add blank, idx=2906, count=339
# Add blank, idx=2926, count=340
# Add blank, idx=2930, count=341
# Add blank, idx=2950, count=342
# Add blank, idx=2953, count=343
# Add blank, idx=2957, count=344
# Add blank, idx=2965, count=345
# Add blank, idx=2979, count=346
# Add blank, idx=2984, count=347
# Add blank, idx=2991, count=348
# (671, 5, 160, 160) (671, 1, 160, 160) inf -inf 1.0 0.0
# Validation data shapes:
# (671, 5, 160, 160)
# (671, 1, 160, 160)

# %% [markdown]
# # Training

# %%
def jaccard_coef(y_true, y_pred):
    # __author__ = Vladimir Iglovikov
    intersection = K.sum(y_true * y_pred, axis=[0, -1, -2])
    sum_ = K.sum(y_true + y_pred, axis=[0, -1, -2])

    jac = (intersection + smooth) / (sum_ - intersection + smooth)

    return K.mean(jac)


def jaccard_coef_int(y_true, y_pred):
    # __author__ = Vladimir Iglovikov
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))

    intersection = K.sum(y_true * y_pred_pos, axis=[0, -1, -2])
    sum_ = K.sum(y_true + y_pred, axis=[0, -1, -2])
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return K.mean(jac)


def calc_jacc(model):
    img = np.load(inDir + '/data/x_val_%d.npy' % N_Cls)
    msk = np.load(inDir + '/data/y_val_%d.npy' % N_Cls)
    
    print("Validation data shapes:")
    print(img.shape)
    print(msk.shape)


    prd = model.predict(img, batch_size=4)
    print(prd.shape, msk.shape)
    avg, trs = [], []

    for i in range(N_Cls):
        t_msk = msk[:, i, :, :]
        t_prd = prd[:, i, :, :]
        t_msk = t_msk.reshape(msk.shape[0] * msk.shape[2], msk.shape[3])
        t_prd = t_prd.reshape(msk.shape[0] * msk.shape[2], msk.shape[3])

        # grid search the threshold
        m, b_tr = 0, 0
        for j in range(10):
            tr = j / 10.0  # threshold
            pred_binary_mask = t_prd > tr

            jk = jaccard_similarity_score(t_msk, pred_binary_mask)
            if jk > m:
                m = jk
                b_tr = tr

        print(i, m, b_tr)
        avg.append(m)
        trs.append(b_tr)

    score = sum(avg) / 10.0
    return prd, score, trs  # trs is the best threshold value (a list, for each of the 10 classes)

# %%
def get_unet_with_indexing():
    inputs = Input((5, ISZ, ISZ))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=1)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=1)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=1)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=1)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(N_Cls, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', 
                  metrics=[jaccard_coef, jaccard_coef_int, 'accuracy'])
    return model

# %%
del x_val
del y_val

x_val, y_val = np.load(inDir + '/data/x_val_%d.npy' % N_Cls), np.load(inDir + '/data/y_val_%d.npy' % N_Cls)
img = np.load(inDir + '/data/x_trn_%d.npy' % N_Cls)
msk = np.load(inDir + '/data/y_trn_%d.npy' % N_Cls)

# %%
del x_trn
del y_trn

x_trn, y_trn = get_patches(img, msk, amt=6000, aug=False)

model = get_unet_with_indexing()
# Out:
# Add blank, idx=0, count=1
# Add blank, idx=30, count=2
# Add blank, idx=38, count=3
# Add blank, idx=80, count=4
# Add blank, idx=107, count=5
# Add blank, idx=152, count=6
# Add blank, idx=215, count=7
# Add blank, idx=240, count=8
# Add blank, idx=264, count=9
# Add blank, idx=342, count=10
# Add blank, idx=370, count=11
# Add blank, idx=405, count=12
# Add blank, idx=438, count=13
# Add blank, idx=453, count=14
# Add blank, idx=476, count=15
# Add blank, idx=497, count=16
# Add blank, idx=505, count=17
# Add blank, idx=509, count=18
# Add blank, idx=519, count=19
# Add blank, idx=520, count=20
# Add blank, idx=553, count=21
# Add blank, idx=590, count=22
# Add blank, idx=611, count=23
# Add blank, idx=645, count=24
# Add blank, idx=662, count=25
# Add blank, idx=710, count=26
# Add blank, idx=712, count=27
# Add blank, idx=743, count=28
# Add blank, idx=752, count=29
# Add blank, idx=779, count=30
# Add blank, idx=781, count=31
# Add blank, idx=793, count=32
# Add blank, idx=818, count=33
# Add blank, idx=832, count=34
# Add blank, idx=840, count=35
# Add blank, idx=861, count=36
# Add blank, idx=913, count=37
# Add blank, idx=940, count=38
# Add blank, idx=948, count=39
# Add blank, idx=1008, count=40
# Add blank, idx=1088, count=41
# Add blank, idx=1109, count=42
# Add blank, idx=1138, count=43
# Add blank, idx=1161, count=44
# Add blank, idx=1162, count=45
# Add blank, idx=1181, count=46
# Add blank, idx=1206, count=47
# Add blank, idx=1209, count=48
# Add blank, idx=1226, count=49
# Add blank, idx=1230, count=50
# Add blank, idx=1234, count=51
# Add blank, idx=1238, count=52
# Add blank, idx=1282, count=53
# Add blank, idx=1316, count=54
# Add blank, idx=1321, count=55
# Add blank, idx=1322, count=56
# Add blank, idx=1324, count=57
# Add blank, idx=1338, count=58
# Add blank, idx=1351, count=59
# Add blank, idx=1387, count=60
# Add blank, idx=1414, count=61
# Add blank, idx=1427, count=62
# Add blank, idx=1444, count=63
# Add blank, idx=1460, count=64
# Add blank, idx=1479, count=65
# Add blank, idx=1481, count=66
# Add blank, idx=1485, count=67
# Add blank, idx=1488, count=68
# Add blank, idx=1507, count=69
# Add blank, idx=1522, count=70
# Add blank, idx=1537, count=71
# Add blank, idx=1551, count=72
# Add blank, idx=1673, count=73
# Add blank, idx=1713, count=74
# Add blank, idx=1735, count=75
# Add blank, idx=1748, count=76
# Add blank, idx=1782, count=77
# Add blank, idx=1804, count=78
# Add blank, idx=1828, count=79
# Add blank, idx=1847, count=80
# Add blank, idx=1871, count=81
# Add blank, idx=1873, count=82
# Add blank, idx=1878, count=83
# Add blank, idx=1889, count=84
# Add blank, idx=1901, count=85
# Add blank, idx=1969, count=86
# Add blank, idx=1991, count=87
# Add blank, idx=1996, count=88
# Add blank, idx=2005, count=89
# Add blank, idx=2032, count=90
# Add blank, idx=2113, count=91
# Add blank, idx=2120, count=92
# Add blank, idx=2154, count=93
# Add blank, idx=2156, count=94
# Add blank, idx=2183, count=95
# Add blank, idx=2187, count=96
# Add blank, idx=2193, count=97
# Add blank, idx=2214, count=98
# Add blank, idx=2231, count=99
# Add blank, idx=2244, count=100
# Add blank, idx=2307, count=101
# Add blank, idx=2344, count=102
# Add blank, idx=2401, count=103
# Add blank, idx=2402, count=104
# Add blank, idx=2405, count=105
# Add blank, idx=2408, count=106
# Add blank, idx=2448, count=107
# Add blank, idx=2526, count=108
# Add blank, idx=2561, count=109
# Add blank, idx=2562, count=110
# Add blank, idx=2601, count=111
# Add blank, idx=2636, count=112
# Add blank, idx=2658, count=113
# Add blank, idx=2659, count=114
# Add blank, idx=2805, count=115
# Add blank, idx=2823, count=116
# Add blank, idx=2842, count=117
# Add blank, idx=2875, count=118
# Add blank, idx=2877, count=119
# Add blank, idx=2900, count=120
# Add blank, idx=2913, count=121
# Add blank, idx=2918, count=122
# Add blank, idx=2922, count=123
# Add blank, idx=2930, count=124
# Add blank, idx=2944, count=125
# Add blank, idx=2950, count=126
# Add blank, idx=2979, count=127
# Add blank, idx=2982, count=128
# Add blank, idx=2985, count=129
# Add blank, idx=3054, count=130
# Add blank, idx=3064, count=131
# Add blank, idx=3094, count=132
# Add blank, idx=3096, count=133
# Add blank, idx=3140, count=134
# Add blank, idx=3144, count=135
# Add blank, idx=3147, count=136
# Add blank, idx=3169, count=137
# Add blank, idx=3172, count=138
# Add blank, idx=3214, count=139
# Add blank, idx=3248, count=140
# Add blank, idx=3253, count=141
# Add blank, idx=3276, count=142
# Add blank, idx=3285, count=143
# Add blank, idx=3350, count=144
# Add blank, idx=3358, count=145
# Add blank, idx=3373, count=146
# Add blank, idx=3382, count=147
# Add blank, idx=3414, count=148
# Add blank, idx=3425, count=149
# Add blank, idx=3426, count=150
# Add blank, idx=3439, count=151
# Add blank, idx=3446, count=152
# Add blank, idx=3489, count=153
# Add blank, idx=3555, count=154
# Add blank, idx=3566, count=155
# Add blank, idx=3572, count=156
# Add blank, idx=3573, count=157
# Add blank, idx=3600, count=158
# Add blank, idx=3707, count=159
# Add blank, idx=3731, count=160
# Add blank, idx=3754, count=161
# Add blank, idx=3776, count=162
# Add blank, idx=3779, count=163
# Add blank, idx=3791, count=164
# Add blank, idx=3802, count=165
# Add blank, idx=3823, count=166
# Add blank, idx=3834, count=167
# Add blank, idx=3847, count=168
# Add blank, idx=3933, count=169
# Add blank, idx=3935, count=170
# Add blank, idx=3998, count=171
# Add blank, idx=3999, count=172
# Add blank, idx=4039, count=173
# Add blank, idx=4048, count=174
# Add blank, idx=4100, count=175
# Add blank, idx=4143, count=176
# Add blank, idx=4196, count=177
# Add blank, idx=4202, count=178
# Add blank, idx=4217, count=179
# Add blank, idx=4223, count=180
# Add blank, idx=4232, count=181
# Add blank, idx=4248, count=182
# Add blank, idx=4269, count=183
# Add blank, idx=4271, count=184
# Add blank, idx=4295, count=185
# Add blank, idx=4298, count=186
# Add blank, idx=4316, count=187
# Add blank, idx=4324, count=188
# Add blank, idx=4338, count=189
# Add blank, idx=4355, count=190
# Add blank, idx=4377, count=191
# Add blank, idx=4379, count=192
# Add blank, idx=4467, count=193
# Add blank, idx=4469, count=194
# Add blank, idx=4497, count=195
# Add blank, idx=4521, count=196
# Add blank, idx=4524, count=197
# Add blank, idx=4563, count=198
# Add blank, idx=4591, count=199
# Add blank, idx=4612, count=200
# Add blank, idx=4621, count=201
# Add blank, idx=4622, count=202
# Add blank, idx=4624, count=203
# Add blank, idx=4659, count=204
# Add blank, idx=4660, count=205
# Add blank, idx=4670, count=206
# Add blank, idx=4681, count=207
# Add blank, idx=4692, count=208
# Add blank, idx=4717, count=209
# Add blank, idx=4751, count=210
# Add blank, idx=4802, count=211
# Add blank, idx=4810, count=212
# Add blank, idx=4849, count=213
# Add blank, idx=4868, count=214
# Add blank, idx=4942, count=215
# Add blank, idx=4967, count=216
# Add blank, idx=4972, count=217
# Add blank, idx=4991, count=218
# Add blank, idx=5001, count=219
# Add blank, idx=5012, count=220
# Add blank, idx=5026, count=221
# Add blank, idx=5031, count=222
# Add blank, idx=5035, count=223
# Add blank, idx=5046, count=224
# Add blank, idx=5080, count=225
# Add blank, idx=5126, count=226
# Add blank, idx=5146, count=227
# Add blank, idx=5153, count=228
# Add blank, idx=5192, count=229
# Add blank, idx=5195, count=230
# Add blank, idx=5218, count=231
# Add blank, idx=5230, count=232
# Add blank, idx=5254, count=233
# Add blank, idx=5273, count=234
# Add blank, idx=5294, count=235
# Add blank, idx=5308, count=236
# Add blank, idx=5324, count=237
# Add blank, idx=5358, count=238
# Add blank, idx=5362, count=239
# Add blank, idx=5373, count=240
# Add blank, idx=5376, count=241
# Add blank, idx=5406, count=242
# Add blank, idx=5434, count=243
# Add blank, idx=5438, count=244
# Add blank, idx=5455, count=245
# Add blank, idx=5462, count=246
# Add blank, idx=5464, count=247
# Add blank, idx=5480, count=248
# Add blank, idx=5495, count=249
# Add blank, idx=5516, count=250
# Add blank, idx=5518, count=251
# Add blank, idx=5566, count=252
# Add blank, idx=5569, count=253
# Add blank, idx=5596, count=254
# Add blank, idx=5632, count=255
# Add blank, idx=5650, count=256
# Add blank, idx=5688, count=257
# Add blank, idx=5698, count=258
# Add blank, idx=5712, count=259
# Add blank, idx=5744, count=260
# Add blank, idx=5754, count=261
# Add blank, idx=5759, count=262
# Add blank, idx=5761, count=263
# Add blank, idx=5768, count=264
# Add blank, idx=5781, count=265
# Add blank, idx=5848, count=266
# Add blank, idx=5849, count=267
# Add blank, idx=5896, count=268
# Add blank, idx=5906, count=269
# Add blank, idx=5956, count=270
# (955, 5, 160, 160) (955, 1, 160, 160) inf -3901.0 1.0 0.0

# %%
x_trn.shape
# Out:
# (955, 5, 160, 160)

# %%
y_trn.shape
# Out:
# (955, 1, 160, 160)

# %%
model.fit(x_trn, y_trn, batch_size=64, epochs=1, verbose=1, shuffle=True,
          validation_data=(x_val, y_val))
# Out:
# Train on 955 samples, validate on 671 samples
# Epoch 1/1
# 955/955 [==============================] - 2085s - loss: nan - jaccard_coef: nan - jaccard_coef_int: nan - acc: 7.6914e-04 - val_loss: nan - val_jaccard_coef: nan - val_jaccard_coef_int: nan - val_acc: 0.0000e+00

# %%
prd, score, trs = calc_jacc(model)
print('val jk', score)
print('trs', trs)
# Out:
# Validation data shapes:
# (671, 5, 160, 160)
# (671, 1, 160, 160)
# (671, 1, 160, 160) (671, 1, 160, 160)
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:87: RuntimeWarning: invalid value encountered in greater
# 0 0.452524217586 0.0
# val jk 0.0452524217586
# trs [0.0]

# %%
now = datetime.now().strftime("%Y%m%d_%H%M%S.h5")
model.save_weights(out_dir+'model_'+now+'.h5')

# %%
del x_trn
del y_trn
x_trn, y_trn = get_patches(img, msk, amt=6000, aug=False)

model.fit(x_trn, y_trn, batch_size=64, epochs=1, verbose=1, shuffle=True,
          validation_data=(x_val, y_val))
# Out:
# Add blank, idx=8, count=1
# Add blank, idx=13, count=2
# Add blank, idx=28, count=3
# Add blank, idx=59, count=4
# Add blank, idx=61, count=5
# Add blank, idx=78, count=6
# Add blank, idx=99, count=7
# Add blank, idx=105, count=8
# Add blank, idx=127, count=9
# Add blank, idx=192, count=10
# Add blank, idx=213, count=11
# Add blank, idx=231, count=12
# Add blank, idx=256, count=13
# Add blank, idx=278, count=14
# Add blank, idx=283, count=15
# Add blank, idx=291, count=16
# Add blank, idx=299, count=17
# Add blank, idx=301, count=18
# Add blank, idx=310, count=19
# Add blank, idx=409, count=20
# Add blank, idx=414, count=21
# Add blank, idx=415, count=22
# Add blank, idx=436, count=23
# Add blank, idx=535, count=24
# Add blank, idx=562, count=25
# Add blank, idx=580, count=26
# Add blank, idx=599, count=27
# Add blank, idx=637, count=28
# Add blank, idx=641, count=29
# Add blank, idx=675, count=30
# Add blank, idx=697, count=31
# Add blank, idx=723, count=32
# Add blank, idx=728, count=33
# Add blank, idx=780, count=34
# Add blank, idx=789, count=35
# Add blank, idx=793, count=36
# Add blank, idx=812, count=37
# Add blank, idx=833, count=38
# Add blank, idx=861, count=39
# Add blank, idx=884, count=40
# Add blank, idx=892, count=41
# Add blank, idx=898, count=42
# Add blank, idx=936, count=43
# Add blank, idx=943, count=44
# Add blank, idx=966, count=45
# Add blank, idx=969, count=46
# Add blank, idx=976, count=47
# Add blank, idx=981, count=48
# Add blank, idx=990, count=49
# Add blank, idx=1015, count=50
# Add blank, idx=1078, count=51
# Add blank, idx=1080, count=52
# Add blank, idx=1085, count=53
# Add blank, idx=1098, count=54
# Add blank, idx=1109, count=55
# Add blank, idx=1118, count=56
# Add blank, idx=1139, count=57
# Add blank, idx=1197, count=58
# Add blank, idx=1240, count=59
# Add blank, idx=1267, count=60
# Add blank, idx=1314, count=61
# Add blank, idx=1329, count=62
# Add blank, idx=1335, count=63
# Add blank, idx=1344, count=64
# Add blank, idx=1357, count=65
# Add blank, idx=1360, count=66
# Add blank, idx=1369, count=67
# Add blank, idx=1375, count=68
# Add blank, idx=1446, count=69
# Add blank, idx=1465, count=70
# Add blank, idx=1494, count=71
# Add blank, idx=1504, count=72
# Add blank, idx=1521, count=73
# Add blank, idx=1526, count=74
# Add blank, idx=1537, count=75
# Add blank, idx=1587, count=76
# Add blank, idx=1634, count=77
# Add blank, idx=1642, count=78
# Add blank, idx=1643, count=79
# Add blank, idx=1650, count=80
# Add blank, idx=1655, count=81
# Add blank, idx=1661, count=82
# Add blank, idx=1701, count=83
# Add blank, idx=1744, count=84
# Add blank, idx=1761, count=85
# Add blank, idx=1766, count=86
# Add blank, idx=1768, count=87
# Add blank, idx=1772, count=88
# Add blank, idx=1782, count=89
# Add blank, idx=1792, count=90
# Add blank, idx=1808, count=91
# Add blank, idx=1809, count=92
# Add blank, idx=1827, count=93
# Add blank, idx=1835, count=94
# Add blank, idx=1875, count=95
# Add blank, idx=1933, count=96
# Add blank, idx=1941, count=97
# Add blank, idx=1981, count=98
# Add blank, idx=1987, count=99
# Add blank, idx=2010, count=100
# Add blank, idx=2032, count=101
# Add blank, idx=2051, count=102
# Add blank, idx=2079, count=103
# Add blank, idx=2105, count=104
# Add blank, idx=2113, count=105
# Add blank, idx=2140, count=106
# Add blank, idx=2145, count=107
# Add blank, idx=2164, count=108
# Add blank, idx=2203, count=109
# Add blank, idx=2220, count=110
# Add blank, idx=2249, count=111
# Add blank, idx=2280, count=112
# Add blank, idx=2284, count=113
# Add blank, idx=2292, count=114
# Add blank, idx=2324, count=115
# Add blank, idx=2328, count=116
# Add blank, idx=2358, count=117
# Add blank, idx=2382, count=118
# Add blank, idx=2385, count=119
# Add blank, idx=2435, count=120
# Add blank, idx=2475, count=121
# Add blank, idx=2481, count=122
# Add blank, idx=2620, count=123
# Add blank, idx=2634, count=124
# Add blank, idx=2690, count=125
# Add blank, idx=2722, count=126
# Add blank, idx=2740, count=127
# Add blank, idx=2759, count=128
# Add blank, idx=2767, count=129
# Add blank, idx=2768, count=130
# Add blank, idx=2783, count=131
# Add blank, idx=2788, count=132
# Add blank, idx=2790, count=133
# Add blank, idx=2798, count=134
# Add blank, idx=2808, count=135
# Add blank, idx=2810, count=136
# Add blank, idx=2879, count=137
# Add blank, idx=2893, count=138
# Add blank, idx=2902, count=139
# Add blank, idx=2949, count=140
# Add blank, idx=3015, count=141
# Add blank, idx=3043, count=142
# Add blank, idx=3052, count=143
# Add blank, idx=3084, count=144
# Add blank, idx=3089, count=145
# Add blank, idx=3090, count=146
# Add blank, idx=3130, count=147
# Add blank, idx=3168, count=148
# Add blank, idx=3213, count=149
# Add blank, idx=3246, count=150
# Add blank, idx=3294, count=151
# Add blank, idx=3315, count=152
# Add blank, idx=3327, count=153
# Add blank, idx=3344, count=154
# Add blank, idx=3353, count=155
# Add blank, idx=3399, count=156
# Add blank, idx=3426, count=157
# Add blank, idx=3490, count=158
# Add blank, idx=3550, count=159
# Add blank, idx=3574, count=160
# Add blank, idx=3611, count=161
# Add blank, idx=3620, count=162
# Add blank, idx=3626, count=163
# Add blank, idx=3650, count=164
# Add blank, idx=3658, count=165
# Add blank, idx=3660, count=166
# Add blank, idx=3669, count=167
# Add blank, idx=3706, count=168
# Add blank, idx=3753, count=169
# Add blank, idx=3767, count=170
# Add blank, idx=3775, count=171
# Add blank, idx=3778, count=172
# Add blank, idx=3789, count=173
# Add blank, idx=3803, count=174
# Add blank, idx=3821, count=175
# Add blank, idx=3861, count=176
# Add blank, idx=3872, count=177
# Add blank, idx=3882, count=178
# Add blank, idx=3906, count=179
# Add blank, idx=3933, count=180
# Add blank, idx=3952, count=181
# Add blank, idx=4000, count=182
# Add blank, idx=4062, count=183
# Add blank, idx=4081, count=184
# Add blank, idx=4088, count=185
# Add blank, idx=4119, count=186
# Add blank, idx=4153, count=187
# Add blank, idx=4162, count=188
# Add blank, idx=4199, count=189
# Add blank, idx=4208, count=190
# Add blank, idx=4228, count=191
# Add blank, idx=4236, count=192
# Add blank, idx=4237, count=193
# Add blank, idx=4248, count=194
# Add blank, idx=4254, count=195
# Add blank, idx=4256, count=196
# Add blank, idx=4269, count=197
# Add blank, idx=4272, count=198
# Add blank, idx=4292, count=199
# Add blank, idx=4326, count=200
# Add blank, idx=4348, count=201
# Add blank, idx=4370, count=202
# Add blank, idx=4371, count=203
# Add blank, idx=4390, count=204
# Add blank, idx=4394, count=205
# Add blank, idx=4420, count=206
# Add blank, idx=4447, count=207
# Add blank, idx=4473, count=208
# Add blank, idx=4490, count=209
# Add blank, idx=4494, count=210
# Add blank, idx=4496, count=211
# Add blank, idx=4497, count=212
# Add blank, idx=4498, count=213
# Add blank, idx=4524, count=214
# Add blank, idx=4541, count=215
# Add blank, idx=4562, count=216
# Add blank, idx=4614, count=217
# Add blank, idx=4638, count=218
# Add blank, idx=4648, count=219
# Add blank, idx=4653, count=220
# Add blank, idx=4655, count=221
# Add blank, idx=4659, count=222
# Add blank, idx=4664, count=223
# Add blank, idx=4740, count=224
# Add blank, idx=4742, count=225
# Add blank, idx=4782, count=226
# Add blank, idx=4813, count=227
# Add blank, idx=4816, count=228
# Add blank, idx=4822, count=229
# Add blank, idx=4847, count=230
# Add blank, idx=4897, count=231
# Add blank, idx=4930, count=232
# Add blank, idx=4937, count=233
# Add blank, idx=4944, count=234
# Add blank, idx=4952, count=235
# Add blank, idx=4986, count=236
# Add blank, idx=4991, count=237
# Add blank, idx=4993, count=238
# Add blank, idx=5004, count=239
# Add blank, idx=5009, count=240
# Add blank, idx=5020, count=241
# Add blank, idx=5025, count=242
# Add blank, idx=5040, count=243
# Add blank, idx=5042, count=244
# Add blank, idx=5090, count=245
# Add blank, idx=5102, count=246
# Add blank, idx=5118, count=247
# Add blank, idx=5137, count=248
# Add blank, idx=5152, count=249
# Add blank, idx=5175, count=250
# Add blank, idx=5188, count=251
# Add blank, idx=5220, count=252
# Add blank, idx=5227, count=253
# Add blank, idx=5288, count=254
# Add blank, idx=5293, count=255
# Add blank, idx=5314, count=256
# Add blank, idx=5361, count=257
# Add blank, idx=5380, count=258
# Add blank, idx=5381, count=259
# Add blank, idx=5392, count=260
# Add blank, idx=5397, count=261
# Add blank, idx=5438, count=262
# Add blank, idx=5465, count=263
# Add blank, idx=5475, count=264
# Add blank, idx=5479, count=265
# Add blank, idx=5506, count=266
# Add blank, idx=5545, count=267
# Add blank, idx=5567, count=268
# Add blank, idx=5674, count=269
# Add blank, idx=5676, count=270
# Add blank, idx=5691, count=271
# Add blank, idx=5704, count=272
# Add blank, idx=5734, count=273
# Add blank, idx=5742, count=274
# Add blank, idx=5753, count=275
# Add blank, idx=5787, count=276
# Add blank, idx=5802, count=277
# Add blank, idx=5822, count=278
# Add blank, idx=5825, count=279
# Add blank, idx=5853, count=280
# Add blank, idx=5868, count=281
# Add blank, idx=5875, count=282
# Add blank, idx=5893, count=283
# Add blank, idx=5898, count=284
# Add blank, idx=5899, count=285
# Add blank, idx=5926, count=286
# Add blank, idx=5981, count=287
# (933, 5, 160, 160) (933, 1, 160, 160) inf -3901.0 1.0 0.0
# Train on 933 samples, validate on 671 samples
# Epoch 1/1
# 933/933 [==============================] - 2048s - loss: nan - jaccard_coef: nan - jaccard_coef_int: nan - acc: 0.0000e+00 - val_loss: nan - val_jaccard_coef: nan - val_jaccard_coef_int: nan - val_acc: 0.0000e+00

# %% [markdown]
# Hmmmm... not learning anything. Lets visualise our training/val data

# %%
print(x_val.shape)
print(y_val.shape)

# %%
folder_names = ["val/3/",
                "val/4/",
                "val/5/",
                "val/ndvi/",
                "val/evi/"]

for i in range(x_val.shape[0]):
    for band_idx, folder_name in enumerate(folder_names):
        mkdir_p("visualise/"+folder_name)        
        
        save_visual_img_patch(x_val, folder_name, sample_idx=i, band=band_idx)
# Out:
# /usr/local/lib/python3.4/dist-packages/scipy/misc/pilutil.py:101: RuntimeWarning: invalid value encountered in multiply
#   bytedata = (data - cmin) * scale + low
# /usr/local/lib/python3.4/dist-packages/scipy/misc/pilutil.py:101: RuntimeWarning: invalid value encountered in subtract
#   bytedata = (data - cmin) * scale + low

# %%
mkdir_p("visualise/val/msk/")

for i in range(y_val.shape[0]):
    save_visual_img_patch(y_val, "val/msk/", sample_idx=i)

# %%
folder_names = ["trn/3/",
                "trn/4/",
                "trn/5/",
                "trn/ndvi/",
                "trn/evi/"]

for i in range(x_trn.shape[0]):
    for band_idx, folder_name in enumerate(folder_names):
        mkdir_p("visualise/"+folder_name)        
        
        save_visual_img_patch(x_trn, folder_name, sample_idx=i, band=band_idx)
# Out:
# /usr/local/lib/python3.4/dist-packages/scipy/misc/pilutil.py:101: RuntimeWarning: invalid value encountered in multiply
#   bytedata = (data - cmin) * scale + low

# %%
mkdir_p("visualise/trn/msk/")

for i in range(y_trn.shape[0]):
    save_visual_img_patch(y_trn, "trn/msk/", sample_idx=i)

# %% [markdown]
# Nothing out of the ordinary - let's add all bands back + indexes

# %% [markdown]
# # All bands + indexes

# %%
def make_val(aug=False):
    print("let's pick some samples for validation")
    img = np.load(inDir + '/data/x_valALL_%d.npy' % N_Cls)
    msk = np.load(inDir + '/data/y_valALL_%d.npy' % N_Cls)
    x, y = get_patches(img, msk, amt=3000, aug=aug)  # amt := attempt (maybe - i.e. attempting to create 3000 patches, without
                                            # percentage area cover threshold.

    print("Validation data shapes:")
    print(x.shape)
    print(y.shape)

    np.save(inDir + '/data/x_val_%d' % N_Cls, x)
    np.save(inDir + '/data/y_val_%d' % N_Cls, y)
    
    
def stick_all_train():
    print("let's stick all imgs together")
    s = 835  # size of the M images (roughly)

    # 25 training images grid
    x = np.zeros((5 * s, 4 * s, 10))      # (8 + ndvi + evi)
    y = np.zeros((5 * s, 4 * s, N_Cls))  # axis=2 denote the class label

    ids = sorted(DF.ImageId.unique())
    print(len(ids))
    
    
    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(4):
            id = ids[1 * i + j]

            img = M(id)
        
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            
            # Add indexes found visually to be useful          
            x[s * i:s * i + s, s * j:s * j + s, :8] = img[:s, :s]

            ndvi, savi, evi = create_indexes(id)
            x[s * i:s * i + s, s * j:s * j + s, 8] = ndvi[:s, :s]
            x[s * i:s * i + s, s * j:s * j + s, 9] = evi[:s, :s]
            
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1)[:s, :s]
    
    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))
    
    np.save(inDir + '/data/x_trn_%d' % N_Cls, x)
    np.save(inDir + '/data/y_trn_%d' % N_Cls, y)
    
    
def stick_all_val():
    print("let's stick all imgs together")
    s = 835  # size of the M images

    # 25 training images grid
    x = np.zeros((5 * s, 1 * s, 10))      # (6+ ndvi + evi)
    y = np.zeros((5 * s, 1 * s, N_Cls))   # axis=2 denote the class label

    ids = sorted(val_DF.ImageId.unique())
    print(len(ids))

    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(1):
            id = ids[1 * i + j]

            img = M(id)
            
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            
            # Add indexes found visually to be useful
            x[s * i:s * i + s, s * j:s * j + s, :8] = img[:s, :s]

            ndvi, savi, evi = create_indexes(id)
            x[s * i:s * i + s, s * j:s * j + s, 8] = ndvi[:s, :s]
            x[s * i:s * i + s, s * j:s * j + s, 9] = evi[:s, :s]
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1, wkt_list_pandas=val_DF)[:s, :s]

    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))

    np.save(inDir + '/data/x_valALL_%d' % N_Cls, x)
    np.save(inDir + '/data/y_valALL_%d' % N_Cls, y)

# %%
stick_all_train()

stick_all_val()
make_val()
# Out:
# let's stick all imgs together
# 20
# (837, 849, 8) 6010_1_2 1.0 0.0
# (837, 849, 8) 6010_4_2 1.0 0.0
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in true_divide
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 849, 8) 6010_4_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 851, 8) 6060_2_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 851, 8) 6060_2_3 1.0 0.0
# (837, 848, 8) 6090_2_0 1.0 0.0
# x shape is:
# (4175, 3340, 10)
# y shape is:
# (4175, 3340, 1)
# 1.0 0.0
# let's stick all imgs together
# 5
# (837, 848, 8) 6010_4_4 1.0 0.0
# (838, 835, 8) 6070_2_3 1.0 0.0
# (837, 848, 8) 6100_2_3 1.0 0.0
# (837, 849, 8) 6110_4_0 1.0 0.0
# (837, 849, 8) 6140_1_2 1.0 0.0
# x shape is:
# (4175, 835, 10)
# y shape is:
# (4175, 835, 1)
# 1.0 0.0
# let's pick some samples for validation
# Add blank, idx=4, count=1
# Add blank, idx=6, count=2
# Add blank, idx=7, count=3
# Add blank, idx=14, count=4
# Add blank, idx=23, count=5
# Add blank, idx=26, count=6
# Add blank, idx=51, count=7
# Add blank, idx=77, count=8
# Add blank, idx=78, count=9
# Add blank, idx=82, count=10
# Add blank, idx=88, count=11
# Add blank, idx=102, count=12
# Add blank, idx=103, count=13
# Add blank, idx=113, count=14
# Add blank, idx=120, count=15
# Add blank, idx=132, count=16
# Add blank, idx=144, count=17
# Add blank, idx=193, count=18
# Add blank, idx=202, count=19
# Add blank, idx=204, count=20
# Add blank, idx=229, count=21
# Add blank, idx=231, count=22
# Add blank, idx=240, count=23
# Add blank, idx=247, count=24
# Add blank, idx=248, count=25
# Add blank, idx=251, count=26
# Add blank, idx=264, count=27
# Add blank, idx=268, count=28
# Add blank, idx=289, count=29
# Add blank, idx=291, count=30
# Add blank, idx=292, count=31
# Add blank, idx=293, count=32
# Add blank, idx=297, count=33
# Add blank, idx=305, count=34
# Add blank, idx=311, count=35
# Add blank, idx=313, count=36
# Add blank, idx=339, count=37
# Add blank, idx=349, count=38
# Add blank, idx=354, count=39
# Add blank, idx=361, count=40
# Add blank, idx=367, count=41
# Add blank, idx=382, count=42
# Add blank, idx=386, count=43
# Add blank, idx=408, count=44
# Add blank, idx=442, count=45
# Add blank, idx=450, count=46
# Add blank, idx=459, count=47
# Add blank, idx=465, count=48
# Add blank, idx=498, count=49
# Add blank, idx=502, count=50
# Add blank, idx=512, count=51
# Add blank, idx=516, count=52
# Add blank, idx=542, count=53
# Add blank, idx=545, count=54
# Add blank, idx=548, count=55
# Add blank, idx=561, count=56
# Add blank, idx=570, count=57
# Add blank, idx=578, count=58
# Add blank, idx=583, count=59
# Add blank, idx=591, count=60
# Add blank, idx=593, count=61
# Add blank, idx=606, count=62
# Add blank, idx=640, count=63
# Add blank, idx=647, count=64
# Add blank, idx=650, count=65
# Add blank, idx=653, count=66
# Add blank, idx=667, count=67
# Add blank, idx=670, count=68
# Add blank, idx=676, count=69
# Add blank, idx=678, count=70
# Add blank, idx=682, count=71
# Add blank, idx=686, count=72
# Add blank, idx=711, count=73
# Add blank, idx=715, count=74
# Add blank, idx=719, count=75
# Add blank, idx=724, count=76
# Add blank, idx=728, count=77
# Add blank, idx=737, count=78
# Add blank, idx=770, count=79
# Add blank, idx=785, count=80
# Add blank, idx=801, count=81
# Add blank, idx=802, count=82
# Add blank, idx=803, count=83
# Add blank, idx=808, count=84
# Add blank, idx=814, count=85
# Add blank, idx=821, count=86
# Add blank, idx=823, count=87
# Add blank, idx=826, count=88
# Add blank, idx=830, count=89
# Add blank, idx=841, count=90
# Add blank, idx=844, count=91
# Add blank, idx=848, count=92
# Add blank, idx=870, count=93
# Add blank, idx=873, count=94
# Add blank, idx=887, count=95
# Add blank, idx=900, count=96
# Add blank, idx=904, count=97
# Add blank, idx=907, count=98
# Add blank, idx=909, count=99
# Add blank, idx=917, count=100
# Add blank, idx=925, count=101
# Add blank, idx=936, count=102
# Add blank, idx=938, count=103
# Add blank, idx=958, count=104
# Add blank, idx=969, count=105
# Add blank, idx=973, count=106
# Add blank, idx=979, count=107
# Add blank, idx=980, count=108
# Add blank, idx=986, count=109
# Add blank, idx=988, count=110
# Add blank, idx=1001, count=111
# Add blank, idx=1003, count=112
# Add blank, idx=1007, count=113
# Add blank, idx=1014, count=114
# Add blank, idx=1015, count=115
# Add blank, idx=1016, count=116
# Add blank, idx=1019, count=117
# Add blank, idx=1030, count=118
# Add blank, idx=1038, count=119
# Add blank, idx=1041, count=120
# Add blank, idx=1044, count=121
# Add blank, idx=1045, count=122
# Add blank, idx=1060, count=123
# Add blank, idx=1080, count=124
# Add blank, idx=1083, count=125
# Add blank, idx=1086, count=126
# Add blank, idx=1097, count=127
# Add blank, idx=1104, count=128
# Add blank, idx=1108, count=129
# Add blank, idx=1109, count=130
# Add blank, idx=1132, count=131
# Add blank, idx=1143, count=132
# Add blank, idx=1147, count=133
# Add blank, idx=1148, count=134
# Add blank, idx=1162, count=135
# Add blank, idx=1170, count=136
# Add blank, idx=1186, count=137
# Add blank, idx=1191, count=138
# Add blank, idx=1193, count=139
# Add blank, idx=1202, count=140
# Add blank, idx=1204, count=141
# Add blank, idx=1205, count=142
# Add blank, idx=1218, count=143
# Add blank, idx=1225, count=144
# Add blank, idx=1231, count=145
# Add blank, idx=1238, count=146
# Add blank, idx=1258, count=147
# Add blank, idx=1265, count=148
# Add blank, idx=1271, count=149
# Add blank, idx=1272, count=150
# Add blank, idx=1273, count=151
# Add blank, idx=1280, count=152
# Add blank, idx=1293, count=153
# Add blank, idx=1300, count=154
# Add blank, idx=1336, count=155
# Add blank, idx=1348, count=156
# Add blank, idx=1350, count=157
# Add blank, idx=1385, count=158
# Add blank, idx=1394, count=159
# Add blank, idx=1398, count=160
# Add blank, idx=1399, count=161
# Add blank, idx=1402, count=162
# Add blank, idx=1411, count=163
# Add blank, idx=1412, count=164
# Add blank, idx=1413, count=165
# Add blank, idx=1428, count=166
# Add blank, idx=1430, count=167
# Add blank, idx=1442, count=168
# Add blank, idx=1453, count=169
# Add blank, idx=1455, count=170
# Add blank, idx=1464, count=171
# Add blank, idx=1472, count=172
# Add blank, idx=1480, count=173
# Add blank, idx=1482, count=174
# Add blank, idx=1492, count=175
# Add blank, idx=1497, count=176
# Add blank, idx=1498, count=177
# Add blank, idx=1502, count=178
# Add blank, idx=1508, count=179
# Add blank, idx=1517, count=180
# Add blank, idx=1544, count=181
# Add blank, idx=1548, count=182
# Add blank, idx=1561, count=183
# Add blank, idx=1568, count=184
# Add blank, idx=1571, count=185
# Add blank, idx=1600, count=186
# Add blank, idx=1621, count=187
# Add blank, idx=1628, count=188
# Add blank, idx=1635, count=189
# Add blank, idx=1642, count=190
# Add blank, idx=1652, count=191
# Add blank, idx=1670, count=192
# Add blank, idx=1671, count=193
# Add blank, idx=1699, count=194
# Add blank, idx=1719, count=195
# Add blank, idx=1738, count=196
# Add blank, idx=1742, count=197
# Add blank, idx=1743, count=198
# Add blank, idx=1745, count=199
# Add blank, idx=1751, count=200
# Add blank, idx=1754, count=201
# Add blank, idx=1788, count=202
# Add blank, idx=1791, count=203
# Add blank, idx=1797, count=204
# Add blank, idx=1808, count=205
# Add blank, idx=1812, count=206
# Add blank, idx=1813, count=207
# Add blank, idx=1821, count=208
# Add blank, idx=1822, count=209
# Add blank, idx=1830, count=210
# Add blank, idx=1856, count=211
# Add blank, idx=1866, count=212
# Add blank, idx=1876, count=213
# Add blank, idx=1878, count=214
# Add blank, idx=1884, count=215
# Add blank, idx=1885, count=216
# Add blank, idx=1886, count=217
# Add blank, idx=1903, count=218
# Add blank, idx=1920, count=219
# Add blank, idx=1922, count=220
# Add blank, idx=1923, count=221
# Add blank, idx=1933, count=222
# Add blank, idx=1951, count=223
# Add blank, idx=1963, count=224
# Add blank, idx=1991, count=225
# Add blank, idx=1994, count=226
# Add blank, idx=1997, count=227
# Add blank, idx=2014, count=228
# Add blank, idx=2019, count=229
# Add blank, idx=2026, count=230
# Add blank, idx=2030, count=231
# Add blank, idx=2031, count=232
# Add blank, idx=2044, count=233
# Add blank, idx=2050, count=234
# Add blank, idx=2051, count=235
# Add blank, idx=2053, count=236
# Add blank, idx=2063, count=237
# Add blank, idx=2064, count=238
# Add blank, idx=2073, count=239
# Add blank, idx=2074, count=240
# Add blank, idx=2085, count=241
# Add blank, idx=2093, count=242
# Add blank, idx=2096, count=243
# Add blank, idx=2113, count=244
# Add blank, idx=2118, count=245
# Add blank, idx=2122, count=246
# Add blank, idx=2125, count=247
# Add blank, idx=2131, count=248
# Add blank, idx=2133, count=249
# Add blank, idx=2136, count=250
# Add blank, idx=2170, count=251
# Add blank, idx=2173, count=252
# Add blank, idx=2174, count=253
# Add blank, idx=2205, count=254
# Add blank, idx=2209, count=255
# Add blank, idx=2212, count=256
# Add blank, idx=2232, count=257
# Add blank, idx=2243, count=258
# Add blank, idx=2250, count=259
# Add blank, idx=2251, count=260
# Add blank, idx=2254, count=261
# Add blank, idx=2268, count=262
# Add blank, idx=2271, count=263
# Add blank, idx=2272, count=264
# Add blank, idx=2292, count=265
# Add blank, idx=2296, count=266
# Add blank, idx=2298, count=267
# Add blank, idx=2328, count=268
# Add blank, idx=2345, count=269
# Add blank, idx=2348, count=270
# Add blank, idx=2357, count=271
# Add blank, idx=2364, count=272
# Add blank, idx=2369, count=273
# Add blank, idx=2374, count=274
# Add blank, idx=2375, count=275
# Add blank, idx=2378, count=276
# Add blank, idx=2380, count=277
# Add blank, idx=2381, count=278
# Add blank, idx=2386, count=279
# Add blank, idx=2404, count=280
# Add blank, idx=2408, count=281
# Add blank, idx=2411, count=282
# Add blank, idx=2414, count=283
# Add blank, idx=2419, count=284
# Add blank, idx=2425, count=285
# Add blank, idx=2432, count=286
# Add blank, idx=2437, count=287
# Add blank, idx=2439, count=288
# Add blank, idx=2458, count=289
# Add blank, idx=2478, count=290
# Add blank, idx=2491, count=291
# Add blank, idx=2505, count=292
# Add blank, idx=2511, count=293
# Add blank, idx=2518, count=294
# Add blank, idx=2527, count=295
# Add blank, idx=2528, count=296
# Add blank, idx=2540, count=297
# Add blank, idx=2562, count=298
# Add blank, idx=2563, count=299
# Add blank, idx=2567, count=300
# Add blank, idx=2573, count=301
# Add blank, idx=2575, count=302
# Add blank, idx=2594, count=303
# Add blank, idx=2596, count=304
# Add blank, idx=2610, count=305
# Add blank, idx=2615, count=306
# Add blank, idx=2617, count=307
# Add blank, idx=2618, count=308
# Add blank, idx=2619, count=309
# Add blank, idx=2637, count=310
# Add blank, idx=2640, count=311
# Add blank, idx=2650, count=312
# Add blank, idx=2655, count=313
# Add blank, idx=2660, count=314
# Add blank, idx=2697, count=315
# Add blank, idx=2710, count=316
# Add blank, idx=2713, count=317
# Add blank, idx=2718, count=318
# Add blank, idx=2724, count=319
# Add blank, idx=2733, count=320
# Add blank, idx=2736, count=321
# Add blank, idx=2738, count=322
# Add blank, idx=2742, count=323
# Add blank, idx=2751, count=324
# Add blank, idx=2760, count=325
# Add blank, idx=2763, count=326
# Add blank, idx=2774, count=327
# Add blank, idx=2778, count=328
# Add blank, idx=2791, count=329
# Add blank, idx=2794, count=330
# Add blank, idx=2799, count=331
# Add blank, idx=2800, count=332
# Add blank, idx=2802, count=333
# Add blank, idx=2805, count=334
# Add blank, idx=2808, count=335
# Add blank, idx=2816, count=336
# Add blank, idx=2822, count=337
# Add blank, idx=2834, count=338
# Add blank, idx=2837, count=339
# Add blank, idx=2838, count=340
# Add blank, idx=2839, count=341
# Add blank, idx=2867, count=342
# Add blank, idx=2868, count=343
# Add blank, idx=2872, count=344
# Add blank, idx=2875, count=345
# Add blank, idx=2885, count=346
# Add blank, idx=2897, count=347
# Add blank, idx=2907, count=348
# Add blank, idx=2940, count=349
# Add blank, idx=2949, count=350
# Add blank, idx=2950, count=351
# Add blank, idx=2951, count=352
# Add blank, idx=2954, count=353
# Add blank, idx=2961, count=354
# Add blank, idx=2971, count=355
# Add blank, idx=2979, count=356
# Add blank, idx=2981, count=357
# Add blank, idx=2983, count=358
# Add blank, idx=2985, count=359
# Add blank, idx=2986, count=360
# Add blank, idx=2996, count=361
# Add blank, idx=2999, count=362
# (731, 10, 160, 160) (731, 1, 160, 160) inf -inf 1.0 0.0
# Validation data shapes:
# (731, 10, 160, 160)
# (731, 1, 160, 160)

# %%
def get_unet_with_indexing_v2():
    inputs = Input((10, ISZ, ISZ))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=1)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=1)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=1)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=1)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(N_Cls, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', 
                  metrics=[jaccard_coef, jaccard_coef_int, 'accuracy'])
    return model

# %%
del x_val
del y_val
del x_trn
del y_trn
del img
del msk

x_val, y_val = np.load(inDir + '/data/x_val_%d.npy' % N_Cls), np.load(inDir + '/data/y_val_%d.npy' % N_Cls)
img = np.load(inDir + '/data/x_trn_%d.npy' % N_Cls)
msk = np.load(inDir + '/data/y_trn_%d.npy' % N_Cls)

model = get_unet_with_indexing_v2()

# %%
print(x_val.shape)
print(y_val.shape)
# Out:
# (731, 10, 160, 160)
# (731, 1, 160, 160)

# %%
x_trn, y_trn = get_patches(img, msk, amt=6000, aug=False)

print(x_trn.shape)
print(y_trn.shape)

model.fit(x_trn, y_trn, batch_size=64, epochs=1, verbose=1, shuffle=True,
          validation_data=(x_val, y_val))
# Out:
# Add blank, idx=7, count=1
# Add blank, idx=62, count=2
# Add blank, idx=72, count=3
# Add blank, idx=141, count=4
# Add blank, idx=151, count=5
# Add blank, idx=158, count=6
# Add blank, idx=173, count=7
# Add blank, idx=199, count=8
# Add blank, idx=204, count=9
# Add blank, idx=220, count=10
# Add blank, idx=252, count=11
# Add blank, idx=254, count=12
# Add blank, idx=255, count=13
# Add blank, idx=264, count=14
# Add blank, idx=307, count=15
# Add blank, idx=317, count=16
# Add blank, idx=367, count=17
# Add blank, idx=385, count=18
# Add blank, idx=396, count=19
# Add blank, idx=437, count=20
# Add blank, idx=453, count=21
# Add blank, idx=460, count=22
# Add blank, idx=486, count=23
# Add blank, idx=517, count=24
# Add blank, idx=564, count=25
# Add blank, idx=578, count=26
# Add blank, idx=587, count=27
# Add blank, idx=590, count=28
# Add blank, idx=614, count=29
# Add blank, idx=637, count=30
# Add blank, idx=743, count=31
# Add blank, idx=779, count=32
# Add blank, idx=820, count=33
# Add blank, idx=840, count=34
# Add blank, idx=847, count=35
# Add blank, idx=849, count=36
# Add blank, idx=855, count=37
# Add blank, idx=860, count=38
# Add blank, idx=862, count=39
# Add blank, idx=876, count=40
# Add blank, idx=884, count=41
# Add blank, idx=911, count=42
# Add blank, idx=940, count=43
# Add blank, idx=970, count=44
# Add blank, idx=979, count=45
# Add blank, idx=990, count=46
# Add blank, idx=991, count=47
# Add blank, idx=1008, count=48
# Add blank, idx=1014, count=49
# Add blank, idx=1030, count=50
# Add blank, idx=1075, count=51
# Add blank, idx=1120, count=52
# Add blank, idx=1138, count=53
# Add blank, idx=1140, count=54
# Add blank, idx=1168, count=55
# Add blank, idx=1227, count=56
# Add blank, idx=1285, count=57
# Add blank, idx=1287, count=58
# Add blank, idx=1306, count=59
# Add blank, idx=1324, count=60
# Add blank, idx=1327, count=61
# Add blank, idx=1348, count=62
# Add blank, idx=1359, count=63
# Add blank, idx=1360, count=64
# Add blank, idx=1386, count=65
# Add blank, idx=1417, count=66
# Add blank, idx=1443, count=67
# Add blank, idx=1447, count=68
# Add blank, idx=1456, count=69
# Add blank, idx=1469, count=70
# Add blank, idx=1551, count=71
# Add blank, idx=1559, count=72
# Add blank, idx=1610, count=73
# Add blank, idx=1612, count=74
# Add blank, idx=1630, count=75
# Add blank, idx=1666, count=76
# Add blank, idx=1683, count=77
# Add blank, idx=1699, count=78
# Add blank, idx=1717, count=79
# Add blank, idx=1757, count=80
# Add blank, idx=1818, count=81
# Add blank, idx=1832, count=82
# Add blank, idx=1833, count=83
# Add blank, idx=1901, count=84
# Add blank, idx=1917, count=85
# Add blank, idx=1925, count=86
# Add blank, idx=1930, count=87
# Add blank, idx=1982, count=88
# Add blank, idx=2002, count=89
# Add blank, idx=2024, count=90
# Add blank, idx=2074, count=91
# Add blank, idx=2082, count=92
# Add blank, idx=2120, count=93
# Add blank, idx=2178, count=94
# Add blank, idx=2179, count=95
# Add blank, idx=2203, count=96
# Add blank, idx=2217, count=97
# Add blank, idx=2226, count=98
# Add blank, idx=2304, count=99
# Add blank, idx=2310, count=100
# Add blank, idx=2329, count=101
# Add blank, idx=2340, count=102
# Add blank, idx=2348, count=103
# Add blank, idx=2364, count=104
# Add blank, idx=2381, count=105
# Add blank, idx=2385, count=106
# Add blank, idx=2400, count=107
# Add blank, idx=2414, count=108
# Add blank, idx=2451, count=109
# Add blank, idx=2509, count=110
# Add blank, idx=2527, count=111
# Add blank, idx=2586, count=112
# Add blank, idx=2594, count=113
# Add blank, idx=2602, count=114
# Add blank, idx=2604, count=115
# Add blank, idx=2626, count=116
# Add blank, idx=2636, count=117
# Add blank, idx=2670, count=118
# Add blank, idx=2689, count=119
# Add blank, idx=2712, count=120
# Add blank, idx=2749, count=121
# Add blank, idx=2789, count=122
# Add blank, idx=2838, count=123
# Add blank, idx=2868, count=124
# Add blank, idx=2965, count=125
# Add blank, idx=2970, count=126
# Add blank, idx=2995, count=127
# Add blank, idx=3021, count=128
# Add blank, idx=3040, count=129
# Add blank, idx=3041, count=130
# Add blank, idx=3071, count=131
# Add blank, idx=3081, count=132
# Add blank, idx=3093, count=133
# Add blank, idx=3119, count=134
# Add blank, idx=3135, count=135
# Add blank, idx=3139, count=136
# Add blank, idx=3159, count=137
# Add blank, idx=3162, count=138
# Add blank, idx=3231, count=139
# Add blank, idx=3256, count=140
# Add blank, idx=3272, count=141
# Add blank, idx=3301, count=142
# Add blank, idx=3307, count=143
# Add blank, idx=3309, count=144
# Add blank, idx=3380, count=145
# Add blank, idx=3383, count=146
# Add blank, idx=3385, count=147
# Add blank, idx=3393, count=148
# Add blank, idx=3395, count=149
# Add blank, idx=3408, count=150
# Add blank, idx=3422, count=151
# Add blank, idx=3429, count=152
# Add blank, idx=3471, count=153
# Add blank, idx=3512, count=154
# Add blank, idx=3526, count=155
# Add blank, idx=3527, count=156
# Add blank, idx=3530, count=157
# Add blank, idx=3590, count=158
# Add blank, idx=3616, count=159
# Add blank, idx=3617, count=160
# Add blank, idx=3703, count=161
# Add blank, idx=3728, count=162
# Add blank, idx=3752, count=163
# Add blank, idx=3753, count=164
# Add blank, idx=3767, count=165
# Add blank, idx=3775, count=166
# Add blank, idx=3798, count=167
# Add blank, idx=3799, count=168
# Add blank, idx=3811, count=169
# Add blank, idx=3817, count=170
# Add blank, idx=3845, count=171
# Add blank, idx=3870, count=172
# Add blank, idx=3880, count=173
# Add blank, idx=3956, count=174
# Add blank, idx=3976, count=175
# Add blank, idx=3977, count=176
# Add blank, idx=3986, count=177
# Add blank, idx=4027, count=178
# Add blank, idx=4077, count=179
# Add blank, idx=4082, count=180
# Add blank, idx=4100, count=181
# Add blank, idx=4144, count=182
# Add blank, idx=4173, count=183
# Add blank, idx=4210, count=184
# Add blank, idx=4212, count=185
# Add blank, idx=4285, count=186
# Add blank, idx=4311, count=187
# Add blank, idx=4340, count=188
# Add blank, idx=4398, count=189
# Add blank, idx=4399, count=190
# Add blank, idx=4406, count=191
# Add blank, idx=4447, count=192
# Add blank, idx=4472, count=193
# Add blank, idx=4477, count=194
# Add blank, idx=4492, count=195
# Add blank, idx=4514, count=196
# Add blank, idx=4517, count=197
# Add blank, idx=4538, count=198
# Add blank, idx=4546, count=199
# Add blank, idx=4562, count=200
# Add blank, idx=4565, count=201
# Add blank, idx=4597, count=202
# Add blank, idx=4622, count=203
# Add blank, idx=4662, count=204
# Add blank, idx=4693, count=205
# Add blank, idx=4698, count=206
# Add blank, idx=4720, count=207
# Add blank, idx=4762, count=208
# Add blank, idx=4773, count=209
# Add blank, idx=4823, count=210
# Add blank, idx=4828, count=211
# Add blank, idx=4849, count=212
# Add blank, idx=4853, count=213
# Add blank, idx=4905, count=214
# Add blank, idx=4907, count=215
# Add blank, idx=4910, count=216
# Add blank, idx=4935, count=217
# Add blank, idx=4976, count=218
# Add blank, idx=4981, count=219
# Add blank, idx=4993, count=220
# Add blank, idx=5014, count=221
# Add blank, idx=5018, count=222
# Add blank, idx=5026, count=223
# Add blank, idx=5117, count=224
# Add blank, idx=5192, count=225
# Add blank, idx=5196, count=226
# Add blank, idx=5202, count=227
# Add blank, idx=5220, count=228
# Add blank, idx=5249, count=229
# Add blank, idx=5257, count=230
# Add blank, idx=5433, count=231
# Add blank, idx=5443, count=232
# Add blank, idx=5450, count=233
# Add blank, idx=5481, count=234
# Add blank, idx=5491, count=235
# Add blank, idx=5505, count=236
# Add blank, idx=5518, count=237
# Add blank, idx=5530, count=238
# Add blank, idx=5546, count=239
# Add blank, idx=5584, count=240
# Add blank, idx=5612, count=241
# Add blank, idx=5659, count=242
# Add blank, idx=5666, count=243
# Add blank, idx=5688, count=244
# Add blank, idx=5711, count=245
# Add blank, idx=5778, count=246
# Add blank, idx=5790, count=247
# Add blank, idx=5797, count=248
# Add blank, idx=5811, count=249
# Add blank, idx=5855, count=250
# Add blank, idx=5866, count=251
# Add blank, idx=5885, count=252
# Add blank, idx=5898, count=253
# Add blank, idx=5909, count=254
# Add blank, idx=5920, count=255
# Add blank, idx=5936, count=256
# Add blank, idx=5940, count=257
# Add blank, idx=5958, count=258
# Add blank, idx=5967, count=259
# Add blank, idx=5992, count=260
# (975, 10, 160, 160) (975, 1, 160, 160) inf -3901.0 1.0 0.0
# (975, 10, 160, 160)
# (975, 1, 160, 160)
# Train on 975 samples, validate on 731 samples
# Epoch 1/1
# 975/975 [==============================] - 2181s - loss: nan - jaccard_coef: nan - jaccard_coef_int: nan - acc: 0.0128 - val_loss: nan - val_jaccard_coef: nan - val_jaccard_coef_int: nan - val_acc: 0.0000e+00

# %%
now = datetime.now().strftime("%Y%m%d_%H%M%S.h5")
model.save_weights(out_dir+'model_'+now+'.h5')

# %% [markdown]
# Hmmm... is there a bug - let's check by going back to square 1.

# %% [markdown]
# # Back to square 1

# %% [markdown]
# Let's also reduce the number of patches per epoch to reduce runtime (i.e. `amt=300` for val and `600` for trn) - also don't regenerate new training data each epoch ("let's overfit this small sample" - JH).

# %%
def make_val(aug=False):
    print("let's pick some samples for validation")
    img = np.load(inDir + '/data/x_valALL_%d.npy' % N_Cls)
    msk = np.load(inDir + '/data/y_valALL_%d.npy' % N_Cls)
    x, y = get_patches(img, msk, amt=300, aug=aug)  # amt := attempt (maybe - i.e. attempting to create 3000 patches, without
                                            # percentage area cover threshold.

    print("Validation data shapes:")
    print(x.shape)
    print(y.shape)

    np.save(inDir + '/data/x_val_%d' % N_Cls, x)
    np.save(inDir + '/data/y_val_%d' % N_Cls, y)
    
    
def stick_all_train():
    print("let's stick all imgs together")
    s = 835  # size of the M images (roughly)

    # 25 training images grid
    x = np.zeros((5 * s, 4 * s, 8))      # (8 + ndvi + evi)
    y = np.zeros((5 * s, 4 * s, N_Cls))  # axis=2 denote the class label

    ids = sorted(DF.ImageId.unique())
    print(len(ids))
    
    
    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(4):
            id = ids[1 * i + j]

            img = M(id)
        
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            
            x[s * i:s * i + s, s * j:s * j + s, :] = img[:s, :s, :] # DOES img[:s, :s] WORK?           
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1)[:s, :s]
    
    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))
    
    np.save(inDir + '/data/x_trn_%d' % N_Cls, x)
    np.save(inDir + '/data/y_trn_%d' % N_Cls, y)
    
    
def stick_all_val():
    print("let's stick all imgs together")
    s = 835  # size of the M images

    # 25 training images grid
    x = np.zeros((5 * s, 1 * s, 8))      # (6+ ndvi + evi)
    y = np.zeros((5 * s, 1 * s, N_Cls))   # axis=2 denote the class label

    ids = sorted(val_DF.ImageId.unique())
    print(len(ids))

    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(1):
            id = ids[1 * i + j]

            img = M(id)
            
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            
            x[s * i:s * i + s, s * j:s * j + s, :] = img[:s, :s, :] # DOES img[:s, :s] WORK?           
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1, wkt_list_pandas=val_DF)[:s, :s]

    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))

    np.save(inDir + '/data/x_valALL_%d' % N_Cls, x)
    np.save(inDir + '/data/y_valALL_%d' % N_Cls, y)

# %%
stick_all_train()

stick_all_val()
make_val()
# Out:
# let's stick all imgs together
# 20
# (837, 849, 8) 6010_1_2 1.0 0.0
# (837, 849, 8) 6010_4_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 849, 8) 6010_4_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 851, 8) 6060_2_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 851, 8) 6060_2_3 1.0 0.0
# (837, 848, 8) 6090_2_0 1.0 0.0
# x shape is:
# (4175, 3340, 8)
# y shape is:
# (4175, 3340, 1)
# 1.0 0.0
# let's stick all imgs together
# 5
# (837, 848, 8) 6010_4_4 1.0 0.0
# (838, 835, 8) 6070_2_3 1.0 0.0
# (837, 848, 8) 6100_2_3 1.0 0.0
# (837, 849, 8) 6110_4_0 1.0 0.0
# (837, 849, 8) 6140_1_2 1.0 0.0
# x shape is:
# (4175, 835, 8)
# y shape is:
# (4175, 835, 1)
# 1.0 0.0
# let's pick some samples for validation
# Add blank, idx=18, count=1
# Add blank, idx=24, count=2
# Add blank, idx=27, count=3
# Add blank, idx=29, count=4
# Add blank, idx=32, count=5
# Add blank, idx=42, count=6
# Add blank, idx=55, count=7
# Add blank, idx=58, count=8
# Add blank, idx=61, count=9
# Add blank, idx=70, count=10
# Add blank, idx=106, count=11
# Add blank, idx=112, count=12
# Add blank, idx=117, count=13
# Add blank, idx=118, count=14
# Add blank, idx=119, count=15
# Add blank, idx=125, count=16
# Add blank, idx=126, count=17
# Add blank, idx=127, count=18
# Add blank, idx=129, count=19
# Add blank, idx=166, count=20
# Add blank, idx=174, count=21
# Add blank, idx=188, count=22
# Add blank, idx=191, count=23
# Add blank, idx=220, count=24
# Add blank, idx=223, count=25
# Add blank, idx=266, count=26
# Add blank, idx=272, count=27
# Add blank, idx=295, count=28
# (69, 8, 160, 160) (69, 1, 160, 160) 1.0 -1.0 1.0 0.0
# Validation data shapes:
# (69, 8, 160, 160)
# (69, 1, 160, 160)

# %%
def get_unet():
    inputs = Input((8, ISZ, ISZ))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=1)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=1)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=1)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=1)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(N_Cls, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', 
                  metrics=[jaccard_coef, jaccard_coef_int, 'accuracy'])
    return model

# %%
x_val, y_val = np.load(inDir + '/data/x_val_%d.npy' % N_Cls), np.load(inDir + '/data/y_val_%d.npy' % N_Cls)
img = np.load(inDir + '/data/x_trn_%d.npy' % N_Cls)
msk = np.load(inDir + '/data/y_trn_%d.npy' % N_Cls)

model = get_unet()

# %% [markdown]
# DON'T regenerate new training data each epoch ("let's overfit this small sample" - JH).
# AND smaller num_samples

# %%
del x_trn
del y_trn
x_trn, y_trn = get_patches(img, msk, amt=600, aug=False)
# Out:
# Add blank, idx=1, count=1
# Add blank, idx=95, count=2
# Add blank, idx=101, count=3
# Add blank, idx=104, count=4
# Add blank, idx=110, count=5
# Add blank, idx=113, count=6
# Add blank, idx=173, count=7
# Add blank, idx=176, count=8
# Add blank, idx=204, count=9
# Add blank, idx=270, count=10
# Add blank, idx=283, count=11
# Add blank, idx=375, count=12
# Add blank, idx=445, count=13
# Add blank, idx=467, count=14
# Add blank, idx=538, count=15
# Add blank, idx=560, count=16
# Add blank, idx=562, count=17
# Add blank, idx=573, count=18
# Add blank, idx=593, count=19
# (98, 8, 160, 160) (98, 1, 160, 160) 1.0 -1.0 1.0 0.0

# %%
model.fit(x_trn, y_trn, batch_size=64, epochs=1, verbose=1, shuffle=True,
          validation_data=(x_val, y_val))
# Out:
# Train on 98 samples, validate on 69 samples
# Epoch 1/1
# 98/98 [==============================] - 216s - loss: 0.6995 - jaccard_coef: 0.2314 - jaccard_coef_int: 0.3502 - acc: 0.4168 - val_loss: 0.6322 - val_jaccard_coef: 0.1986 - val_jaccard_coef_int: 2.3687e-05 - val_acc: 0.7269

# %% [markdown]
# # M + NDVI

# %% [markdown]
# Same again (i.e. no new training data each epoch AND smaller num_samples)...

# %%
def make_val(aug=False):
    print("let's pick some samples for validation")
    img = np.load(inDir + '/data/x_valALL_%d.npy' % N_Cls)
    msk = np.load(inDir + '/data/y_valALL_%d.npy' % N_Cls)
    x, y = get_patches(img, msk, amt=300, aug=aug)  # amt := attempt (maybe - i.e. attempting to create 3000 patches, without
                                            # percentage area cover threshold.

    print("Validation data shapes:")
    print(x.shape)
    print(y.shape)

    np.save(inDir + '/data/x_val_%d' % N_Cls, x)
    np.save(inDir + '/data/y_val_%d' % N_Cls, y)
    
    
def stick_all_train():
    print("let's stick all imgs together")
    s = 835  # size of the M images (roughly)

    # 25 training images grid
    x = np.zeros((5 * s, 4 * s, 8+1))      # (8 + ndvi + evi)
    y = np.zeros((5 * s, 4 * s, N_Cls))  # axis=2 denote the class label

    ids = sorted(DF.ImageId.unique())
    print(len(ids))
    
    
    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(4):
            id = ids[1 * i + j]

            img = M(id)
        
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            
            x[s * i:s * i + s, s * j:s * j + s, :8] = img[:s, :s, :]
            
            # Add indexes from above
            ndvi, savi, evi = create_indexes(id)
            x[s * i:s * i + s, s * j:s * j + s, 8] = ndvi[:s, :s]   
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1)[:s, :s]
    
    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))
    
    np.save(inDir + '/data/x_trn_%d' % N_Cls, x)
    np.save(inDir + '/data/y_trn_%d' % N_Cls, y)
    
    
def stick_all_val():
    print("let's stick all imgs together")
    s = 835  # size of the M images

    # 25 training images grid
    x = np.zeros((5 * s, 1 * s, 8+1))      # (6+ ndvi + evi)
    y = np.zeros((5 * s, 1 * s, N_Cls))   # axis=2 denote the class label

    ids = sorted(val_DF.ImageId.unique())
    print(len(ids))

    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(1):
            id = ids[1 * i + j]

            img = M(id)
            
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            
            x[s * i:s * i + s, s * j:s * j + s, :8] = img[:s, :s, :]
            
            # Add indexes from above
            ndvi, savi, evi = create_indexes(id)
            x[s * i:s * i + s, s * j:s * j + s, 8] = ndvi[:s, :s]
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1, wkt_list_pandas=val_DF)[:s, :s]

    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))

    np.save(inDir + '/data/x_valALL_%d' % N_Cls, x)
    np.save(inDir + '/data/y_valALL_%d' % N_Cls, y)

# %%
stick_all_train()

stick_all_val()
make_val()
# Out:
# let's stick all imgs together
# 20
# (837, 849, 8) 6010_1_2 1.0 0.0
# (837, 849, 8) 6010_4_2 1.0 0.0
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in true_divide
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 849, 8) 6010_4_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 851, 8) 6060_2_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 851, 8) 6060_2_3 1.0 0.0
# (837, 848, 8) 6090_2_0 1.0 0.0
# x shape is:
# (4175, 3340, 9)
# y shape is:
# (4175, 3340, 1)
# 1.0 0.0
# let's stick all imgs together
# 5
# (837, 848, 8) 6010_4_4 1.0 0.0
# (838, 835, 8) 6070_2_3 1.0 0.0
# (837, 848, 8) 6100_2_3 1.0 0.0
# (837, 849, 8) 6110_4_0 1.0 0.0
# (837, 849, 8) 6140_1_2 1.0 0.0
# x shape is:
# (4175, 835, 9)
# y shape is:
# (4175, 835, 1)
# 1.0 0.0
# let's pick some samples for validation
# Add blank, idx=2, count=1
# Add blank, idx=10, count=2
# Add blank, idx=14, count=3
# Add blank, idx=22, count=4
# Add blank, idx=24, count=5
# Add blank, idx=26, count=6
# Add blank, idx=31, count=7
# Add blank, idx=41, count=8
# Add blank, idx=51, count=9
# Add blank, idx=68, count=10
# Add blank, idx=89, count=11
# Add blank, idx=90, count=12
# Add blank, idx=103, count=13
# Add blank, idx=104, count=14
# Add blank, idx=124, count=15
# Add blank, idx=133, count=16
# Add blank, idx=149, count=17
# Add blank, idx=157, count=18
# Add blank, idx=166, count=19
# Add blank, idx=171, count=20
# Add blank, idx=188, count=21
# Add blank, idx=198, count=22
# Add blank, idx=212, count=23
# Add blank, idx=227, count=24
# Add blank, idx=231, count=25
# Add blank, idx=243, count=26
# Add blank, idx=247, count=27
# Add blank, idx=254, count=28
# Add blank, idx=266, count=29
# Add blank, idx=270, count=30
# Add blank, idx=280, count=31
# (71, 9, 160, 160) (71, 1, 160, 160) 1.0 -1.51785713434 1.0 0.0
# Validation data shapes:
# (71, 9, 160, 160)
# (71, 1, 160, 160)

# %%
def get_unet_M_NDVI():
    inputs = Input((8+1, ISZ, ISZ))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=1)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=1)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=1)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=1)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(N_Cls, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', 
                  metrics=[jaccard_coef, jaccard_coef_int, 'accuracy'])
    return model

# %%
x_val, y_val = np.load(inDir + '/data/x_val_%d.npy' % N_Cls), np.load(inDir + '/data/y_val_%d.npy' % N_Cls)
img = np.load(inDir + '/data/x_trn_%d.npy' % N_Cls)
msk = np.load(inDir + '/data/y_trn_%d.npy' % N_Cls)

model = get_unet_M_NDVI()

# %%
del x_trn
del y_trn
x_trn, y_trn = get_patches(img, msk, amt=600, aug=False)
# Out:
# Add blank, idx=5, count=1
# Add blank, idx=11, count=2
# Add blank, idx=12, count=3
# Add blank, idx=33, count=4
# Add blank, idx=42, count=5
# Add blank, idx=66, count=6
# Add blank, idx=74, count=7
# Add blank, idx=121, count=8
# Add blank, idx=235, count=9
# Add blank, idx=238, count=10
# Add blank, idx=310, count=11
# Add blank, idx=327, count=12
# Add blank, idx=346, count=13
# Add blank, idx=406, count=14
# Add blank, idx=436, count=15
# Add blank, idx=455, count=16
# Add blank, idx=472, count=17
# Add blank, idx=474, count=18
# Add blank, idx=478, count=19
# Add blank, idx=483, count=20
# Add blank, idx=519, count=21
# Add blank, idx=544, count=22
# Add blank, idx=561, count=23
# (84, 9, 160, 160) (84, 1, 160, 160) 1.0 -1.0 1.0 0.0

# %%
model.fit(x_trn, y_trn, batch_size=64, epochs=1, verbose=1, shuffle=True,
          validation_data=(x_val, y_val))
# Out:
# Train on 84 samples, validate on 71 samples
# Epoch 1/1
# 84/84 [==============================] - 195s - loss: 0.6770 - jaccard_coef: 0.2039 - jaccard_coef_int: 0.0043 - acc: 0.7312 - val_loss: 0.5740 - val_jaccard_coef: 0.1718 - val_jaccard_coef_int: 2.0693e-18 - val_acc: 0.7375

# %% [markdown]
# Hmmm... Maybe EVI is breaking it:

# %% [markdown]
# # M + EVI

# %% [markdown]
# Same again (i.e. no new training data each epoch AND smaller num_samples) + EVI...

# %%
def make_val(aug=False):
    print("let's pick some samples for validation")
    img = np.load(inDir + '/data/x_valALL_%d.npy' % N_Cls)
    msk = np.load(inDir + '/data/y_valALL_%d.npy' % N_Cls)
    x, y = get_patches(img, msk, amt=300, aug=aug)  # amt := attempt (maybe - i.e. attempting to create 3000 patches, without
                                            # percentage area cover threshold.

    print("Validation data shapes:")
    print(x.shape)
    print(y.shape)

    np.save(inDir + '/data/x_val_%d' % N_Cls, x)
    np.save(inDir + '/data/y_val_%d' % N_Cls, y)
    
    
def stick_all_train():
    print("let's stick all imgs together")
    s = 835  # size of the M images (roughly)

    # 25 training images grid
    x = np.zeros((5 * s, 4 * s, 8+1))      # (8 + ndvi + evi)
    y = np.zeros((5 * s, 4 * s, N_Cls))  # axis=2 denote the class label

    ids = sorted(DF.ImageId.unique())
    print(len(ids))
    
    
    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(4):
            id = ids[1 * i + j]

            img = M(id)
        
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            
            x[s * i:s * i + s, s * j:s * j + s, :8] = img[:s, :s, :]
            
            # Add indexes from above
            ndvi, savi, evi = create_indexes(id)
            x[s * i:s * i + s, s * j:s * j + s, 8] = evi[:s, :s]   
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1)[:s, :s]
    
    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))
    
    np.save(inDir + '/data/x_trn_%d' % N_Cls, x)
    np.save(inDir + '/data/y_trn_%d' % N_Cls, y)
    
    
def stick_all_val():
    print("let's stick all imgs together")
    s = 835  # size of the M images

    # 25 training images grid
    x = np.zeros((5 * s, 1 * s, 8+1))      # (6+ ndvi + evi)
    y = np.zeros((5 * s, 1 * s, N_Cls))   # axis=2 denote the class label

    ids = sorted(val_DF.ImageId.unique())
    print(len(ids))

    # x start grid position (based on image size)
    for i in range(5):
        # y start grid position (based on image size)
        for j in range(1):
            id = ids[1 * i + j]

            img = M(id)
            
            img = stretch_n(img)
            print(img.shape, id, np.amax(img), np.amin(img))
            
            x[s * i:s * i + s, s * j:s * j + s, :8] = img[:s, :s, :]
            
            # Add indexes from above
            ndvi, savi, evi = create_indexes(id)
            x[s * i:s * i + s, s * j:s * j + s, 8] = evi[:s, :s]
            
            # generate training masks by class
            for z in range(N_Cls):
                y[s * i:s * i + s, s * j:s * j + s, z] = generate_mask_for_image_and_class(
                    (img.shape[0], img.shape[1]), id, z + 1, wkt_list_pandas=val_DF)[:s, :s]

    print("x shape is:")
    print(x.shape)
    print("y shape is:")
    print(y.shape)

    print(np.amax(y), np.amin(y))

    np.save(inDir + '/data/x_valALL_%d' % N_Cls, x)
    np.save(inDir + '/data/y_valALL_%d' % N_Cls, y)

# %%
stick_all_train()

stick_all_val()
make_val()
# Out:
# let's stick all imgs together
# 20
# (837, 849, 8) 6010_1_2 1.0 0.0
# (837, 849, 8) 6010_4_2 1.0 0.0
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in true_divide
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 849, 8) 6010_4_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 848, 8) 6040_1_0 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 848, 8) 6040_1_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 851, 8) 6060_2_3 1.0 0.0
# (837, 848, 8) 6040_2_2 1.0 0.0
# (837, 846, 8) 6040_4_4 1.0 0.0
# (837, 851, 8) 6060_2_3 1.0 0.0
# (837, 848, 8) 6090_2_0 1.0 0.0
# x shape is:
# (4175, 3340, 9)
# y shape is:
# (4175, 3340, 1)
# 1.0 0.0
# let's stick all imgs together
# 5
# (837, 848, 8) 6010_4_4 1.0 0.0
# (838, 835, 8) 6070_2_3 1.0 0.0
# (837, 848, 8) 6100_2_3 1.0 0.0
# (837, 849, 8) 6110_4_0 1.0 0.0
# (837, 849, 8) 6140_1_2 1.0 0.0
# x shape is:
# (4175, 835, 9)
# y shape is:
# (4175, 835, 1)
# 1.0 0.0
# let's pick some samples for validation
# Add blank, idx=1, count=1
# Add blank, idx=36, count=2
# Add blank, idx=47, count=3
# Add blank, idx=49, count=4
# Add blank, idx=61, count=5
# Add blank, idx=62, count=6
# Add blank, idx=64, count=7
# Add blank, idx=66, count=8
# Add blank, idx=71, count=9
# Add blank, idx=83, count=10
# Add blank, idx=93, count=11
# Add blank, idx=97, count=12
# Add blank, idx=109, count=13
# Add blank, idx=121, count=14
# Add blank, idx=123, count=15
# Add blank, idx=128, count=16
# Add blank, idx=130, count=17
# Add blank, idx=134, count=18
# Add blank, idx=139, count=19
# Add blank, idx=152, count=20
# Add blank, idx=154, count=21
# Add blank, idx=177, count=22
# Add blank, idx=179, count=23
# Add blank, idx=188, count=24
# Add blank, idx=190, count=25
# Add blank, idx=194, count=26
# Add blank, idx=204, count=27
# Add blank, idx=223, count=28
# Add blank, idx=229, count=29
# Add blank, idx=230, count=30
# Add blank, idx=232, count=31
# Add blank, idx=233, count=32
# Add blank, idx=248, count=33
# Add blank, idx=252, count=34
# Add blank, idx=257, count=35
# Add blank, idx=264, count=36
# Add blank, idx=280, count=37
# Add blank, idx=282, count=38
# Add blank, idx=283, count=39
# Add blank, idx=295, count=40
# Add blank, idx=296, count=41
# Add blank, idx=299, count=42
# (76, 9, 160, 160) (76, 1, 160, 160) inf -inf 1.0 0.0
# Validation data shapes:
# (76, 9, 160, 160)
# (76, 1, 160, 160)

# %%
def get_unet_M_EVI():
    inputs = Input((8+1, ISZ, ISZ))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=1)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=1)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=1)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=1)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(N_Cls, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', 
                  metrics=[jaccard_coef, jaccard_coef_int, 'accuracy'])
    return model

# %%
x_val, y_val = np.load(inDir + '/data/x_val_%d.npy' % N_Cls), np.load(inDir + '/data/y_val_%d.npy' % N_Cls)
img = np.load(inDir + '/data/x_trn_%d.npy' % N_Cls)
msk = np.load(inDir + '/data/y_trn_%d.npy' % N_Cls)

model = get_unet_M_EVI()

# %%
del x_trn
del y_trn
x_trn, y_trn = get_patches(img, msk, amt=600, aug=False)

# %%
model.fit(x_trn, y_trn, batch_size=64, epochs=1, verbose=1, shuffle=True,
          validation_data=(x_val, y_val))
# Out:
# Train on 106 samples, validate on 76 samples
# Epoch 1/1
# 106/106 [==============================] - 235s - loss: nan - jaccard_coef: nan - jaccard_coef_int: nan - acc: 0.1387 - val_loss: nan - val_jaccard_coef: nan - val_jaccard_coef_int: nan - val_acc: 0.0000e+00

# %% [markdown]
# # BINGO - EVI is the coporate

# %% [markdown]
# Lets start a clean notebook.
